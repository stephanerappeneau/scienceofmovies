# %% [markdown]
# # Retrieve imdbID from a CSV list of directors

# %%
import numpy as np
import pandas as pd
import time
from bs4 import BeautifulSoup
import json
import requests
import random

# %%
# Loading 90k directors who made the 350k movies
df = pd.read_csv("90 000 directors awards.csv", encoding='utf-8', sep=",",index_col=0,low_memory=False)
df[:5]
# Out:
#               name  gender  movies_nb  fidelity_rel  fidelity_abs  \
# 0   Aki Kaurismäki     2.0         30           2.1            62
# 1   Allison Anders     1.0          9           0.2             2
# 2  Stephen Hopkins     2.0         14           0.5             7
# 3     Timo Novotny     2.0          5           0.0             0
# 4       Marc Meyer     2.0          2           0.0             0
#
#    awards_retrieved   tmdbID     imdbID
# 0                 0    16767  nm0442454
# 1                 0     3110  nm0025978
# 2                 0     2042  nm0394280
# 3                 0    34833  nm1119183
# 4                 0  1405205  nm0583259

# %%
storage_frequency=5000
processed=0

for i in range(len(df)):
    if str(df.loc[i,"imdbID"])=="0":
        director = df.loc[i,"name"].replace(" ","%20")

        #let's get tmdb_id from director_name
        query_for_tmdbID = "https://api.themoviedb.org/3/search/person?api_key=04fe0efd7c6e8c505128686c70ae5825&query="+director
        results = requests.get(query_for_tmdbID)
        dic_results = json.loads(results.text)
        try:
            tmdbID = dic_results["results"][0]["id"]
            #let's get imdb_id from tmdb_id
            query_for_imdbID = "https://api.themoviedb.org/3/person/"+str(tmdbID)+"/external_ids?api_key=04fe0efd7c6e8c505128686c70ae5825"
            results = requests.get(query_for_imdbID)
            dic_results = json.loads(results.text)
            imdbID = dic_results["imdb_id"]
            print(director+"["+str(i)+"]:imdbID = "+imdbID)
        except:
            tmdbID=0
            imdbID=0
        
        df.loc[i,"tmdbID"]=tmdbID
        df.loc[i,"imdbID"]=imdbID

        processed+=1
        #save file every 5000 exec in case it crashes
        if processed>storage_frequency:
            processed=0
            df.to_csv("90 000 directors awards.csv", encoding='utf-8', sep=",")

# %% [markdown]
# director_name="Jackie Chan"
#
# #let's get tmdb_id from director_name
# director = director_name.replace(" ","%20")
# query_for_tmdbID = "https://api.themoviedb.org/3/search/person?api_key=04fe0efd7c6e8c505128686c70ae5825&query="+director
# results = requests.get(query_for_tmdbID)
# dic_results = json.loads(results.text)
# try:
#     tmdbID = dic_results["results"][0]["id"]
#
#     #let's get imdb_id from tmdb_id
#     query_for_imdbID = "https://api.themoviedb.org/3/person/"+str(tmdbID)+"/external_ids?api_key=04fe0efd7c6e8c505128686c70ae5825"
#     results = requests.get(query_for_imdbID)
#     dic_results = json.loads(results.text)
#     imdbID = dic_results["imdb_id"]
#     print(str(i)+","+director+":imdbID = "+imdbID)
# except:
#     print("director not found")

# %%
# Loading 90k directors who made the 350k movies
df = pd.read_csv("90 000 directors awards.csv", encoding='utf-8', sep=",",index_col=0,low_memory=False)
df_award = pd.read_csv("90 000 directors awards retrieved.csv", encoding='utf-8', sep=",",index_col=0,low_memory=False)

df[:5]
# Out:
#               name  gender  movies_nb  fidelity_rel  fidelity_abs  \
# 0   Aki Kaurismäki     2.0         30           2.1            62
# 1   Allison Anders     1.0          9           0.2             2
# 2  Stephen Hopkins     2.0         14           0.5             7
# 3     Timo Novotny     2.0          5           0.0             0
# 4       Marc Meyer     2.0          2           0.0             0
#
#    awards_retrieved   tmdbID     imdbID
# 0                 0    16767  nm0442454
# 1                 0     3110  nm0025978
# 2                 0     2042  nm0394280
# 3                 0    34833  nm1119183
# 4                 0  1405205  nm0583259

# %%
from IPython.display import clear_output
save_every_often=0
clear_output()

for i in range(len(df)):
    #if director award already retrieved, skip
    director_name=df.loc[i,"name"]
    if df.loc[i,"imdbID"]=="0" or df.loc[i,"awards_retrieved"]==1:
        #print("Skipping "+str(i)+"th row, for "+director_name)
        continue
    
    print("Processing "+str(i)+"th row, for "+director_name)
    found_N_awards=0
    
    #if any award already scrapped, delete them to start again
    df_award= df_award[df_award["name"] != director_name]
    
    imdbID=df.loc[i,"imdbID"]
    #query IMDB
    url = "http://www.imdb.com/name/"+imdbID+"/awards"
    r  = requests.get(url)
    data = r.text
    soup = BeautifulSoup(data,"lxml")

    # Find all of the text between paragraph tags and strip out the html
    itag=0
    collection_tag =soup.find_all()
    while itag<len(collection_tag):
        tag=collection_tag[itag]
        tagtext = tag.text.lower()
        #We stop at each award_ceremony, to get all award_years
        if tag.name=="h3" and director_name.lower() not in tagtext and "imdb" not in tagtext and "user" not in tagtext :
            ceremony = tag.text
            #let's go through each year and stop at next H3 tag
            allow_next=True
            while allow_next:
                itag+=1
                tag=collection_tag[itag]
                #let's go through all tags and find outcome(s)/category(s) for each year
                stay_on_tag=True
                for key,value in tag.attrs.items():
                    if not stay_on_tag:
                        break
                    if key=="class":
                        if value[0]=="award_year":
                            year=int(collection_tag[itag].text)
                            stay_on_tag=False
                        elif value[0]=="award_outcome":                        
                            outcome=collection_tag[itag+1].text
                        elif value[0]=="award_category":
                            category=collection_tag[itag].text
                            #we should have a complete row : name / ceremony / category / outcome
                            new_row=len(df_award)+1
                            found_N_awards+=1
                            df_award.loc[new_row,["name"]]=director_name
                            df_award.loc[new_row,["ceremony"]]=ceremony
                            df_award.loc[new_row,["year"]]=year
                            df_award.loc[new_row,["category"]]=category
                            df_award.loc[new_row,["outcome"]]=outcome

                #if you bump on a next ceremony come back one step before and analyse it
                if tag.name=="h3":
                    allow_next=False
                    itag-=1
        itag+=1
        
    #this director is DONE
    df.loc[i,"awards_retrieved"]=1
    print(director_name+" done, found "+str(found_N_awards)+" awards, that's number "+str(i))
    
    #save every 500 directors
    save_every_often+=1
    if save_every_often>500:
        df_award.to_csv("90 000 directors awards retrieved.csv", encoding='utf-8', sep=",")
        df.to_csv("90 000 directors awards.csv", encoding='utf-8', sep=",")
        save_every_often=0

    #Avoid spamming imdb
    time.sleep(random.random()*5)
# Out:
# Processing 1829th row, for Ken Dixon
# Ken Dixon done, found 0 awards, that's number 1829
# Processing 1830th row, for Tony Richardson
# Tony Richardson done, found 22 awards, that's number 1830
# Processing 1831th row, for Beverly Sebastian
# Beverly Sebastian done, found 0 awards, that's number 1831
# Processing 1832th row, for Michael Darlow
# Michael Darlow done, found 4 awards, that's number 1832
# Processing 1833th row, for Jonathan Lucas
# Jonathan Lucas done, found 0 awards, that's number 1833
# Processing 1834th row, for John Lamb
# John Lamb done, found 0 awards, that's number 1834
# Processing 1835th row, for Claudio Fragasso
# Claudio Fragasso done, found 3 awards, that's number 1835
# Processing 1836th row, for I. Robert Levy
# I. Robert Levy done, found 1 awards, that's number 1836
# Processing 1838th row, for Franziska Meyer Price
# Franziska Meyer Price done, found 1 awards, that's number 1838
# Processing 1839th row, for Roy Andersson
# Roy Andersson done, found 40 awards, that's number 1839
# Processing 1840th row, for Clark Johnson
# Clark Johnson done, found 13 awards, that's number 1840
# Processing 1841th row, for Melvin Van Peebles
# Melvin Van Peebles done, found 11 awards, that's number 1841
# Processing 1842th row, for Gabriela Zerhau
# Gabriela Zerhau done, found 4 awards, that's number 1842
# Processing 1843th row, for Thomas Freundner
# Thomas Freundner done, found 2 awards, that's number 1843
# Processing 1844th row, for Ulrich Zrenner
# Ulrich Zrenner done, found 0 awards, that's number 1844
# Processing 1845th row, for René Heisig
# René Heisig done, found 5 awards, that's number 1845
# Processing 1846th row, for Owen Hurley
# Owen Hurley done, found 3 awards, that's number 1846
# Processing 1847th row, for Marc Klasfeld
# Marc Klasfeld done, found 0 awards, that's number 1847
# Processing 1848th row, for Christian von Castelberg
# Christian von Castelberg done, found 1 awards, that's number 1848
# Processing 1849th row, for Francesco Rosi
# Francesco Rosi done, found 59 awards, that's number 1849
# Processing 1850th row, for Ryûhei Kitamura
# Ryûhei Kitamura done, found 14 awards, that's number 1850
# Processing 1851th row, for Reha Erdem
# Reha Erdem done, found 46 awards, that's number 1851
# Processing 1852th row, for Tom Dey
# Tom Dey done, found 0 awards, that's number 1852
# Processing 1853th row, for Luis Mandoki
# Luis Mandoki done, found 9 awards, that's number 1853
# Processing 1854th row, for Chris Sivertson
# Chris Sivertson done, found 2 awards, that's number 1854
# Processing 1856th row, for Eugen York
# Eugen York done, found 2 awards, that's number 1856
# Processing 1857th row, for Stephan Komandarev
# Stephan Komandarev done, found 24 awards, that's number 1857
# Processing 1858th row, for Sherry Hormann
# Sherry Hormann done, found 8 awards, that's number 1858
# Processing 1859th row, for Nagisa Ōshima
# Nagisa Ōshima done, found 19 awards, that's number 1859
# Processing 1860th row, for Antoine de Caunes
# Antoine de Caunes done, found 5 awards, that's number 1860
# Processing 1861th row, for Heiner Lauterbach
# Heiner Lauterbach done, found 13 awards, that's number 1861
# Processing 1862th row, for Fritz Kirchhoff
# Fritz Kirchhoff done, found 0 awards, that's number 1862
# Processing 1863th row, for Werner Hochbaum
# Werner Hochbaum done, found 3 awards, that's number 1863
# Processing 1864th row, for Shusuke Kaneko
# Shusuke Kaneko done, found 7 awards, that's number 1864
# Processing 1865th row, for Günter Schlesinger
# Günter Schlesinger done, found 0 awards, that's number 1865
# Processing 1866th row, for Klaus Wildenhahn
# Klaus Wildenhahn done, found 0 awards, that's number 1866
# Processing 1867th row, for John Derek
# John Derek done, found 8 awards, that's number 1867
# Processing 1868th row, for Adam Simon
# Adam Simon done, found 1 awards, that's number 1868
# Processing 1869th row, for Rolf Randolf
# Rolf Randolf done, found 0 awards, that's number 1869
# Processing 1870th row, for Hermann Kugelstadt
# Hermann Kugelstadt done, found 0 awards, that's number 1870
# Processing 1871th row, for Erich Waschneck
# Erich Waschneck done, found 2 awards, that's number 1871
# Processing 1872th row, for Roberto Bianchi Montero
# Roberto Bianchi Montero done, found 0 awards, that's number 1872
# Processing 1873th row, for Alfred Weidenmann
# Alfred Weidenmann done, found 4 awards, that's number 1873
# Processing 1874th row, for Sean Penn
# Sean Penn done, found 163 awards, that's number 1874
# Processing 1875th row, for William Wiard
# William Wiard done, found 0 awards, that's number 1875
# Processing 1876th row, for Charles Guggenheim
# Charles Guggenheim done, found 17 awards, that's number 1876
# Processing 1877th row, for Claus Muras
# Claus Muras done, found 0 awards, that's number 1877
# Processing 1878th row, for José Bénazéraf
# José Bénazéraf done, found 0 awards, that's number 1878
# Processing 1879th row, for Franz Marischka
# Franz Marischka done, found 0 awards, that's number 1879
# Processing 1880th row, for Georg Einerdinger
# Georg Einerdinger done, found 0 awards, that's number 1880
# Processing 1881th row, for Olf Fischer
# Olf Fischer done, found 0 awards, that's number 1881
# Processing 1882th row, for Ákos Ráthonyi
# Ákos Ráthonyi done, found 1 awards, that's number 1882
# Processing 1883th row, for Florian Gallenberger
# Florian Gallenberger done, found 18 awards, that's number 1883
# Processing 1885th row, for Dietrich Haugk
# Dietrich Haugk done, found 1 awards, that's number 1885
# Processing 1886th row, for Robin Swicord
# Robin Swicord done, found 15 awards, that's number 1886
# Processing 1887th row, for Martin Walz
# Martin Walz done, found 4 awards, that's number 1887
# Processing 1888th row, for Hubert Sauper
# Hubert Sauper done, found 29 awards, that's number 1888
# Processing 1889th row, for George Ratliff
# George Ratliff done, found 10 awards, that's number 1889
# Processing 1890th row, for Ted Gaier
# Ted Gaier done, found 1 awards, that's number 1890
# Processing 1891th row, for Max Michel
# Max Michel done, found 0 awards, that's number 1891
# Processing 1892th row, for Eberhard Fechner
# Eberhard Fechner done, found 4 awards, that's number 1892
# Processing 1893th row, for Teresa Pelegri
# Teresa Pelegri done, found 11 awards, that's number 1893
# Processing 1894th row, for John Hamburg
# John Hamburg done, found 1 awards, that's number 1894
# Processing 1895th row, for Gene Wilder
# Gene Wilder done, found 14 awards, that's number 1895
# Processing 1896th row, for Marco Serafini
# Marco Serafini done, found 0 awards, that's number 1896
# Processing 1897th row, for Alan Gibson
# Alan Gibson done, found 1 awards, that's number 1897
# Processing 1898th row, for John Glyn-Jones
# John Glyn-Jones done, found 0 awards, that's number 1898
# Processing 1899th row, for Lenard Fritz Krawinkel
# Lenard Fritz Krawinkel done, found 2 awards, that's number 1899
# Processing 1900th row, for Daniel Lind Lagerlöf
# Daniel Lind Lagerlöf done, found 5 awards, that's number 1900
# Processing 1901th row, for Hans Quest
# Hans Quest done, found 0 awards, that's number 1901
# Processing 1902th row, for Emily Young
# Emily Young done, found 0 awards, that's number 1902
# Processing 1903th row, for Poul Bang
# Poul Bang done, found 0 awards, that's number 1903
# Processing 1904th row, for Iain Dilthey
# Iain Dilthey done, found 11 awards, that's number 1904
# Processing 1905th row, for Géza von Cziffra
# Géza von Cziffra done, found 1 awards, that's number 1905
# Processing 1906th row, for Elis Ellis
# Elis Ellis done, found 0 awards, that's number 1906
# Processing 1907th row, for Petter Næss
# Petter Næss done, found 35 awards, that's number 1907
# Processing 1908th row, for Volker Lechtenbrink
# Volker Lechtenbrink done, found 0 awards, that's number 1908
# Processing 1909th row, for Norbert Terry
# Norbert Terry done, found 0 awards, that's number 1909
# Processing 1910th row, for Hans Deppe
# Hans Deppe done, found 0 awards, that's number 1910
# Processing 1911th row, for Phil Jutzi
# Phil Jutzi done, found 0 awards, that's number 1911
# Processing 1912th row, for Franz Wenzler
# Franz Wenzler done, found 0 awards, that's number 1912
# Processing 1913th row, for Wallace Wolodarsky
# Wallace Wolodarsky done, found 10 awards, that's number 1913
# Processing 1914th row, for Lajos Koltai
# Lajos Koltai done, found 13 awards, that's number 1914
# Processing 1915th row, for Paul Stanley
# Paul Stanley done, found 1 awards, that's number 1915
# Processing 1916th row, for Frank Tashlin
# Frank Tashlin done, found 2 awards, that's number 1916
# Processing 1917th row, for Vadim Derbenyov
# Vadim Derbenyov done, found 1 awards, that's number 1917
# Processing 1918th row, for Robert Michael Lewis
# Robert Michael Lewis done, found 1 awards, that's number 1918
# Processing 1919th row, for Dick Lowry
# Dick Lowry done, found 1 awards, that's number 1919
# Processing 1920th row, for Robert Moore
# Robert Moore done, found 1 awards, that's number 1920
# Processing 1921th row, for Henry Edwards
# Henry Edwards done, found 2 awards, that's number 1921
# Processing 1922th row, for Keith Boak
# Keith Boak done, found 0 awards, that's number 1922
# Processing 1923th row, for Dean Semler
# Dean Semler done, found 24 awards, that's number 1923
# Processing 1924th row, for Leslie S. Hiscott
# Leslie S. Hiscott done, found 0 awards, that's number 1924
# Processing 1925th row, for Barbet Schroeder
# Barbet Schroeder done, found 21 awards, that's number 1925
# Processing 1926th row, for Kevin Reynolds
# Kevin Reynolds done, found 7 awards, that's number 1926
# Processing 1927th row, for Claus Peter Witt
# Claus Peter Witt done, found 1 awards, that's number 1927
# Processing 1928th row, for Til Schweiger
# Til Schweiger done, found 32 awards, that's number 1928
# Processing 1929th row, for Géla Babluani
# Géla Babluani done, found 12 awards, that's number 1929
# Processing 1930th row, for Joseph McGrath
# Joseph McGrath done, found 1 awards, that's number 1930
# Processing 1931th row, for Andreas Linke
# Andreas Linke done, found 3 awards, that's number 1931
# Processing 1932th row, for Lou Antonio
# Lou Antonio done, found 4 awards, that's number 1932
# Processing 1933th row, for Lawrence Gordon Clark
# Lawrence Gordon Clark done, found 2 awards, that's number 1933
# Processing 1934th row, for Gary Nelson
# Gary Nelson done, found 3 awards, that's number 1934
# Processing 1935th row, for Jean Kemm
# Jean Kemm done, found 0 awards, that's number 1935
# Processing 1936th row, for Richard Curson Smith
# Richard Curson Smith done, found 1 awards, that's number 1936
# Processing 1937th row, for Sergei Ursulyak
# Sergei Ursulyak done, found 14 awards, that's number 1937
# Processing 1938th row, for Jason Xenopoulos
# Jason Xenopoulos done, found 3 awards, that's number 1938
# Processing 1939th row, for Bob Spiers
# Bob Spiers done, found 8 awards, that's number 1939
# Processing 1941th row, for Georg Jacoby
# Georg Jacoby done, found 1 awards, that's number 1941
# Processing 1942th row, for Arthur Robison
# Arthur Robison done, found 0 awards, that's number 1942
# Processing 1943th row, for Michael Kreindl
# Michael Kreindl done, found 0 awards, that's number 1943
# Processing 1944th row, for Stephan Wagner
# Stephan Wagner done, found 16 awards, that's number 1944
# Processing 1945th row, for Michael Gutmann
# Michael Gutmann done, found 8 awards, that's number 1945
# Processing 1946th row, for Georg Asagaroff
# Georg Asagaroff done, found 0 awards, that's number 1946
# Processing 1947th row, for Dietmar Klein
# Dietmar Klein done, found 1 awards, that's number 1947
# Processing 1948th row, for Erik Ode
# Erik Ode done, found 7 awards, that's number 1948
# Processing 1949th row, for Bettina Woernle
# Bettina Woernle done, found 1 awards, that's number 1949
# Processing 1950th row, for Mike Eschmann
# Mike Eschmann done, found 1 awards, that's number 1950
# Processing 1951th row, for Paul Breuls
# Paul Breuls done, found 0 awards, that's number 1951
# Processing 1952th row, for Wolfgang Liebeneiner
# Wolfgang Liebeneiner done, found 6 awards, that's number 1952
# Processing 1953th row, for Heinz Dunkhase
# Heinz Dunkhase done, found 0 awards, that's number 1953
# Processing 1954th row, for Gloria Behrens
# Gloria Behrens done, found 2 awards, that's number 1954
# Processing 1955th row, for Karl Kases
# Karl Kases done, found 0 awards, that's number 1955
# Processing 1956th row, for Lars Montag
# Lars Montag done, found 2 awards, that's number 1956
# Processing 1957th row, for Robert van Ackeren
# Robert van Ackeren done, found 3 awards, that's number 1957
# Processing 1958th row, for Christoph Böll
# Christoph Böll done, found 1 awards, that's number 1958
# Processing 1960th row, for Ed Radtke
# Ed Radtke done, found 15 awards, that's number 1960
# Processing 1961th row, for Lee Stanley
# Lee Stanley done, found 0 awards, that's number 1961
# Processing 1962th row, for Alf Sjöberg
# Alf Sjöberg done, found 10 awards, that's number 1962
# Processing 1963th row, for Anne Fontaine
# Anne Fontaine done, found 21 awards, that's number 1963
# Processing 1964th row, for Dominik Betz
# Dominik Betz done, found 0 awards, that's number 1964
# Processing 1965th row, for Andreas Marschall
# Andreas Marschall done, found 4 awards, that's number 1965
# Processing 1966th row, for Nana Dzhordzhadze
# Nana Dzhordzhadze done, found 7 awards, that's number 1966
# Processing 1967th row, for Manfred Stelzer
# Manfred Stelzer done, found 4 awards, that's number 1967
# Processing 1968th row, for Rolf Silber
# Rolf Silber done, found 5 awards, that's number 1968
# Processing 1969th row, for Felix Dünnemann
# Felix Dünnemann done, found 0 awards, that's number 1969
# Processing 1970th row, for Sylvia Hoffmann
# Sylvia Hoffmann done, found 0 awards, that's number 1970
# Processing 1971th row, for Christiane Balthasar
# Christiane Balthasar done, found 1 awards, that's number 1971
# Processing 1972th row, for Clemens M. Schönborn
# Clemens M. Schönborn done, found 2 awards, that's number 1972
# Processing 1973th row, for Otto Meyer
# Otto Meyer done, found 0 awards, that's number 1973
# Processing 1974th row, for Helmut Metzger
# Helmut Metzger done, found 0 awards, that's number 1974
# Processing 1975th row, for Michael Sturminger
# Michael Sturminger done, found 5 awards, that's number 1975
# Processing 1976th row, for Edzard Onneken
# Edzard Onneken done, found 2 awards, that's number 1976
# Processing 1978th row, for Thomas Berger
# Thomas Berger done, found 3 awards, that's number 1978
# Processing 1979th row, for Klaus Emmerich
# Klaus Emmerich done, found 3 awards, that's number 1979
# Processing 1980th row, for Hans-Jürgen Tögel
# Hans-Jürgen Tögel done, found 0 awards, that's number 1980
# Processing 1981th row, for Thomas Jacob
# Thomas Jacob done, found 0 awards, that's number 1981
# Processing 1982th row, for Curt Bois
# Curt Bois done, found 2 awards, that's number 1982
# Processing 1983th row, for Marian Bruchholz
# Marian Bruchholz done, found 0 awards, that's number 1983
# Processing 1984th row, for Carl Boese
# Carl Boese done, found 0 awards, that's number 1984
# Processing 1985th row, for Julian Pölsler
# Julian Pölsler done, found 14 awards, that's number 1985
# Processing 1986th row, for Anthony Hickox
# Anthony Hickox done, found 6 awards, that's number 1986
# Processing 1987th row, for Brad Mirman
# Brad Mirman done, found 2 awards, that's number 1987
# Processing 1988th row, for Bill Duke
# Bill Duke done, found 13 awards, that's number 1988
# Processing 1989th row, for Hans Heinrich
# Hans Heinrich done, found 0 awards, that's number 1989
# Processing 1990th row, for David McNally
# David McNally done, found 0 awards, that's number 1990
# Processing 1991th row, for Christian-Jaque
# Christian-Jaque done, found 10 awards, that's number 1991
# Processing 1992th row, for Lutz Konermann
# Lutz Konermann done, found 11 awards, that's number 1992
# Processing 1993th row, for Tony Mitchell
# Tony Mitchell done, found 1 awards, that's number 1993
# Processing 1994th row, for Vivian Naefe
# Vivian Naefe done, found 6 awards, that's number 1994
# Processing 1995th row, for Zoltan Spirandelli
# Zoltan Spirandelli done, found 5 awards, that's number 1995
# Processing 1996th row, for Barry Shear
# Barry Shear done, found 3 awards, that's number 1996
# Processing 1997th row, for Kaspar Heidelbach
# Kaspar Heidelbach done, found 8 awards, that's number 1997
# Processing 1998th row, for Holger Barthel
# Holger Barthel done, found 1 awards, that's number 1998
# Processing 1999th row, for Matthias Tiefenbacher
# Matthias Tiefenbacher done, found 1 awards, that's number 1999
# Processing 2000th row, for James Foley
# James Foley done, found 6 awards, that's number 2000
# Processing 2001th row, for Valeria Bruni Tedeschi
# Valeria Bruni Tedeschi done, found 52 awards, that's number 2001
# Processing 2002th row, for Karsten Wichniarz
# Karsten Wichniarz done, found 0 awards, that's number 2002
# Processing 2003th row, for E.A. Dupont
# E.A. Dupont done, found 2 awards, that's number 2003
# Processing 2004th row, for Hans Steinhoff
# Hans Steinhoff done, found 3 awards, that's number 2004
# Processing 2005th row, for František Čáp
# František Čáp done, found 5 awards, that's number 2005
# Processing 2006th row, for Walter Bockmayer
# Walter Bockmayer done, found 2 awards, that's number 2006
# Processing 2007th row, for Peter Sämann
# Peter Sämann done, found 1 awards, that's number 2007
# Processing 2008th row, for Wolfgang Schleif
# Wolfgang Schleif done, found 0 awards, that's number 2008
# Processing 2009th row, for Frank Guthke
# Frank Guthke done, found 0 awards, that's number 2009
# Processing 2010th row, for Peter Weck
# Peter Weck done, found 6 awards, that's number 2010
# Processing 2011th row, for Bill Bennett
# Bill Bennett done, found 0 awards, that's number 2011
# Processing 2012th row, for Carlo Jelavic
# Carlo Jelavic done, found 2 awards, that's number 2012
# Processing 2014th row, for Utz Weber
# Utz Weber done, found 0 awards, that's number 2014
# Processing 2015th row, for Imo Moszkowicz
# Imo Moszkowicz done, found 1 awards, that's number 2015
# Processing 2016th row, for Shira Geffen
# Shira Geffen done, found 16 awards, that's number 2016
# Processing 2018th row, for Werner Possardt
# Werner Possardt done, found 1 awards, that's number 2018
# Processing 2019th row, for Manuel Siebenmann
# Manuel Siebenmann done, found 0 awards, that's number 2019
# Processing 2020th row, for Sergio Corbucci
# Sergio Corbucci done, found 1 awards, that's number 2020
# Processing 2021th row, for Christine Kabisch
# Christine Kabisch done, found 0 awards, that's number 2021
# Processing 2022th row, for Josh Broecker
# Josh Broecker done, found 0 awards, that's number 2022
# Processing 2023th row, for Ekachai Uekrongtham
# Ekachai Uekrongtham done, found 6 awards, that's number 2023
# Processing 2024th row, for Rainer Kaufmann
# Rainer Kaufmann done, found 25 awards, that's number 2024
# Processing 2025th row, for Robert-Adrian Pejo
# Robert-Adrian Pejo done, found 7 awards, that's number 2025
# Processing 2026th row, for Klaus Lemke
# Klaus Lemke done, found 1 awards, that's number 2026
# Processing 2027th row, for Jim Johnston
# Jim Johnston done, found 0 awards, that's number 2027
# Processing 2028th row, for Frederik Du Chau
# Frederik Du Chau done, found 0 awards, that's number 2028
# Processing 2029th row, for Larry Brand
# Larry Brand done, found 4 awards, that's number 2029
# Processing 2030th row, for Eric Hendershot
# Eric Hendershot done, found 1 awards, that's number 2030
# Processing 2031th row, for Maren Ade
# Maren Ade done, found 61 awards, that's number 2031
# Processing 2032th row, for Carsten Fiebeler
# Carsten Fiebeler done, found 4 awards, that's number 2032
# Processing 2033th row, for Martin Eigler
# Martin Eigler done, found 5 awards, that's number 2033
# Processing 2034th row, for Diethard Klante
# Diethard Klante done, found 2 awards, that's number 2034
# Processing 2035th row, for Anna Justice
# Anna Justice done, found 11 awards, that's number 2035
# Processing 2036th row, for Thomas Grube
# Thomas Grube done, found 0 awards, that's number 2036
# Processing 2037th row, for Gaël Morel
# Gaël Morel done, found 5 awards, that's number 2037
# Processing 2038th row, for Troy Cook
# Troy Cook done, found 0 awards, that's number 2038
# Processing 2040th row, for Carl Reiner
# Carl Reiner done, found 37 awards, that's number 2040
# Processing 2041th row, for Marcus Adams
# Marcus Adams done, found 0 awards, that's number 2041
# Processing 2042th row, for Frank D. Gilroy
# Frank D. Gilroy done, found 5 awards, that's number 2042
# Processing 2043th row, for Tim Hill
# Tim Hill done, found 2 awards, that's number 2043
# Processing 2044th row, for Kevin Spacey
# Kevin Spacey done, found 130 awards, that's number 2044
# Processing 2045th row, for Steve Binder
# Steve Binder done, found 9 awards, that's number 2045
# Processing 2046th row, for Bill Anderson
# Bill Anderson done, found 0 awards, that's number 2046
# Processing 2047th row, for Andrés Aros
# Andrés Aros done, found 0 awards, that's number 2047
# Processing 2048th row, for Figen Ünsal
# Figen Ünsal done, found 0 awards, that's number 2048
# Processing 2049th row, for Frédéric Fisbach
# Frédéric Fisbach done, found 0 awards, that's number 2049
# Processing 2050th row, for Frank Marshall
# Frank Marshall done, found 36 awards, that's number 2050
# Processing 2051th row, for Thomas Kronthaler
# Thomas Kronthaler done, found 1 awards, that's number 2051
# Processing 2052th row, for Shuki Levy
# Shuki Levy done, found 0 awards, that's number 2052
# Processing 2053th row, for Rainer Erler
# Rainer Erler done, found 4 awards, that's number 2053
# Processing 2054th row, for Rudolf Schündler
# Rudolf Schündler done, found 0 awards, that's number 2054
# Processing 2055th row, for Douglas Wolfsperger
# Douglas Wolfsperger done, found 3 awards, that's number 2055
# Processing 2056th row, for Danielo Devaux
# Danielo Devaux done, found 0 awards, that's number 2056
# Processing 2057th row, for Niki Stein
# Niki Stein done, found 10 awards, that's number 2057
# Processing 2058th row, for Jay Chandrasekhar
# Jay Chandrasekhar done, found 9 awards, that's number 2058
# Processing 2059th row, for Jobst Oetzmann
# Jobst Oetzmann done, found 5 awards, that's number 2059
# Processing 2060th row, for John Farrow
# John Farrow done, found 6 awards, that's number 2060
# Processing 2061th row, for Kasi Lemmons
# Kasi Lemmons done, found 12 awards, that's number 2061
# Processing 2062th row, for Alexander Pickl
# Alexander Pickl done, found 0 awards, that's number 2062
# Processing 2063th row, for Juan Antonio Bayona
# Juan Antonio Bayona done, found 41 awards, that's number 2063
# Processing 2064th row, for Bernhard Stephan
# Bernhard Stephan done, found 2 awards, that's number 2064
# Processing 2065th row, for Rodman Flender
# Rodman Flender done, found 0 awards, that's number 2065
# Processing 2067th row, for Eric Champnella
# Eric Champnella done, found 1 awards, that's number 2067
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-1a90c61e53c6> in <module>()
#      77
#      78     #Avoid spamming imdb
# ---> 79     time.sleep(random.random()*5)
#
# KeyboardInterrupt:

# %%
df_award.to_csv("90 000 directors awards retrieved.csv", encoding='utf-8', sep=",")
df.to_csv("90 000 directors awards.csv", encoding='utf-8', sep=",")

# %%
#count won & nominated
df["simplified_outcome"]="Nominated"
df.loc[df["outcome"]=="Won","simplified_outcome"]="Won"
group = df.groupby(by=["year","simplified_outcome"]).count()

#chart won & nominated
min_year=df["year"].min()
max_year=df["year"].max()+1

won_serie=pd.Series(index=range(min_year,max_year))
nominated_serie=pd.Series(index=range(min_year,max_year))

for i in range(min_year,max_year):
    won_serie[i]=0
    nominated_serie[i]=0

for i in range(len(group.index)):
    if group.index[i][1]=="Won":
        won_serie[group.index[i][0]]=group.iloc[i]["name"]
    if group.index[i][1]=="Nominated":
        nominated_serie[group.index[i][0]]=group.iloc[i]["name"]
        
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.bar(range(min_year,max_year), won_serie, color = 'red')
plt.bar(range(min_year,max_year), nominated_serie, color = 'orange', bottom = won_serie)
plt.show()

# %%
##### df["queried"]=0
df["awards_total"]=0


#Let's retrieve the awards from imdb
for i in range(len(df)):
    imdbID = str(df.loc[i,"imdbID"])
    awards_total=0
    if imdbID[0:2]=="nm" and df.loc[i,"queried"]==0:
        #query IMDB
        url = "http://www.imdb.com/name/"+imdbID+"/awards"
        r  = requests.get(url)
        data = r.text
        soup = BeautifulSoup(data,"lxml")

        #Browse for awards
        for tag in soup.find_all('td', class_='award_outcome'):
            award_name = tag.find_all('span',class_='award_category')[0].text
            outcome = tag.find_all('b')[0].text

            #check for existence of award column else create it
            if df.columns.contains(award_name)==False:
                df[award_name]=0
            if df.columns.contains(award_name+"_won")==False:
                df[award_name+"_won"]=0
            if df.columns.contains(award_name+"_nominated")==False:
                df[award_name+"_nominated"]=0

            #count awards won & nominated & sum
            df.loc[i,award_name]+=1
            awards_total+=1
            if outcome.lower()=="won":
                df.loc[i,award_name+"_won"]+=1
            if outcome.lower()=="nominated":
                df.loc[i,award_name+"_nominated"]+=1

        print(df.loc[i,"name"]+", found "+str(awards_total)+" total awards")
        df.loc[i,"queried"]=1
        df.loc[i,"awards_total"]=awards_total
        #Avoid spamming imdb
        time.sleep(random.random()*10)

# %%
df.shape
