# %%
# IMPORTANT : si l'execution déclenche une erreur et demande nltk.download, 
# faire executer ces 2 lignes : 
# nltk.download('punkt')
# nltk.download("stopwords")

# %%
import requests
import nltk
import re

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from sklearn.cluster import KMeans
from string import punctuation
#Initiatlisation du troncateur de mot
st=LancasterStemmer()
#fabrication de ma liste de stopwords
custo_stopwords = set(stopwords.words('english')+list(punctuation)+["film","director","born"])

#---------------------------------------------
# FONCTION
# input : director name (case insensitive)
# output : a dictionary of (word;frequency) based on wikipedia summary
#---------------------------------------------
def GetWikipediaTokenizedSummary(director):
    # Récupération de la page exacte wikipedia (après redirection) à partir du nom de l'auteur non normalisé
    director.replace(" ","+")
    mysearchURL = "https://en.wikipedia.org/w/index.php?search="+director
    mysummaryURL = "https://en.wikipedia.org/w/api.php?format=json&action=query&prop=extracts&redirects=true&exintro&explaintext&titles="
    http = requests.get(mysearchURL)
    #On vire les 30 premiers caractères pour trouver le nom normalisé de l'auteur
    exactURL = mysummaryURL + http.url[30:]
    #Récupération du résumé
    fullresults= requests.get(exactURL).text
    summaryindex = fullresults.find("extract")
    summary =fullresults[summaryindex+10:-5]

    #on vire les caractères spéciaux
    summary.encode('ascii', 'replace')

    #Tokenisation
    sents = sent_tokenize(summary)
    words=[word_tokenize(sent) for sent in sents]

    #Nettoyage de la liste des mots selon certains critères, et décompte
    final_words = dict()
    for sent in words:
        for word in sent:
            word = word.lower()

            # On ignore le nom de l'auteur
            found=False
            for director_part in director.split(" "):
                if word.find(director_part.lower())!=-1:
                    found=True
            if found:
                continue

            #Finalement je ne tronque pas les mots, ça gêne l'interpretation
            #word = st.stem(word)

            # On ignore les mots avec des digits ou antislash dans la liste des stopwords
            if word in custo_stopwords or re.search("[0-9\\\\]+", word):
                continue
            # On ignore les mots de 2 lettres
            if len(word)<3 :
                continue

            #Si on arrive là alors on peut compter le mot    
            if word in final_words:
                final_words[word] += 1
            else:
                final_words[word] = 1
    return final_words
#Si on veut afficher le résultat en triant par occurences décroissantes
#for key in sorted(final_words, key=final_words.get, reverse=True):
#    print(key+":"+str(final_words[key]))

# %%
# Le plan
# 1. Récupérer pour les 250 réalisateurs les mieux notés en moyenne
# 2. Créer une matrice géante, index = réalisateur, colonnes = tous les mots
# 3. Appliquer une pondération IDF (pondérer chaque mot par l'inverse de la fréquence)
# 4. Lancer un algo de clustering

#Step 1
df = pd.read_csv("top250_acclaimed_directors.csv", sep=";", low_memory=False, names = ["id", "director_name"])
df.set_index("director_name",inplace=True)
df.drop("id",axis=1,inplace=True)

# %%
x=0
#Step 2
for x in range(len(df)):
    dict_tokens = GetWikipediaTokenizedSummary(df.iloc[x].name)
    print("Retrieving ("+str(x)+ "/" + str(len(df)) +") summary for : "+df.iloc[x].name+","+str(len(dict_tokens))+" distinct words")
    for word in dict_tokens:
        label = df.iloc[x].name
        df.loc[label,word]=dict_tokens[word]
    x+=1
# defaulting des valeurs NaN
df.fillna(0, inplace=True)
df_backup = df.copy()
# Out:
# Retrieving (0/250) summary for : Todd Kessler,17 distinct words
# Retrieving (1/250) summary for : John Krokidas,12 distinct words
# Retrieving (2/250) summary for : Josh Boone,7 distinct words
# Retrieving (3/250) summary for : David Foenkinos,22 distinct words
# Retrieving (4/250) summary for : Michael Grandage,11 distinct words
# Retrieving (5/250) summary for : Lake Bell,45 distinct words
# Retrieving (6/250) summary for : Bruce Timm,19 distinct words
# Retrieving (7/250) summary for : Charlie Kaufman,64 distinct words
# Retrieving (8/250) summary for : Houda Benyamina,29 distinct words
# Retrieving (9/250) summary for : Chris McKay,38 distinct words
# Retrieving (10/250) summary for : Jonathan Dayton,33 distinct words
# Retrieving (11/250) summary for : Louis D'Esposito,76 distinct words
# Retrieving (12/250) summary for : Marco Berger,46 distinct words
# Retrieving (13/250) summary for : Jan Komasa,7 distinct words
# Retrieving (14/250) summary for : John Kahrs,50 distinct words
# Retrieving (15/250) summary for : Frank Pavich,66 distinct words
# Retrieving (16/250) summary for : Orlando von Einsiedel,51 distinct words
# Retrieving (17/250) summary for : Garth Davis,47 distinct words
# Retrieving (18/250) summary for : Rajkumar Hirani,17 distinct words
# Retrieving (19/250) summary for : Theodore Melfi,22 distinct words
# Retrieving (20/250) summary for : Adam Curtis,31 distinct words
# Retrieving (21/250) summary for : Yann Arthus-Bertrand,12 distinct words
# Retrieving (22/250) summary for : Quentin Tarantino,205 distinct words
# Retrieving (23/250) summary for : Banksy,94 distinct words
# Retrieving (24/250) summary for : Kerry Conran,14 distinct words
# Retrieving (25/250) summary for : Louie Psihoyos,26 distinct words
# Retrieving (26/250) summary for : Chad Stahelski,26 distinct words
# Retrieving (27/250) summary for : Paddy Considine,120 distinct words
# Retrieving (28/250) summary for : Tamara Jenkins,14 distinct words
# Retrieving (29/250) summary for : Mark Osborne,6 distinct words
# Retrieving (30/250) summary for : Tony Kaye,8 distinct words
# Retrieving (31/250) summary for : Ron Fricke,70 distinct words
# Retrieving (32/250) summary for : Oriol Paulo,3 distinct words
# Retrieving (33/250) summary for : Jan Pinkava,13 distinct words
# Retrieving (34/250) summary for : Saschka Unseld,7 distinct words
# Retrieving (35/250) summary for : Paul Dugdale,7 distinct words
# Retrieving (36/250) summary for : Nicholaus Goossen,3 distinct words
# Retrieving (37/250) summary for : Donovan Cook,108 distinct words
# Retrieving (38/250) summary for : Joshua Oppenheimer,19 distinct words
# Retrieving (39/250) summary for : Lee Hae-Jun,11 distinct words
# Retrieving (40/250) summary for : Thea Sharrock,9 distinct words
# Retrieving (41/250) summary for : Edward Yang,22 distinct words
# Retrieving (42/250) summary for : Tetsuya Nakashima,39 distinct words
# Retrieving (43/250) summary for : Satoshi Kon,33 distinct words
# Retrieving (44/250) summary for : René Laloux,4 distinct words
# Retrieving (45/250) summary for : Henri-Georges Clouzot,131 distinct words
# Retrieving (46/250) summary for : Peter Lepeniotis,41 distinct words
# Retrieving (47/250) summary for : Ben Chanan,7 distinct words
# Retrieving (48/250) summary for : Mike Cahill,24 distinct words
# Retrieving (49/250) summary for : Hiroyuki Okiura,10 distinct words
# Retrieving (50/250) summary for : Daniel Ragussis,7 distinct words
# Retrieving (51/250) summary for : Arturo Brachetti,17 distinct words
# Retrieving (52/250) summary for : Stephen Chbosky,48 distinct words
# Retrieving (53/250) summary for : Tomm Moore,34 distinct words
# Retrieving (54/250) summary for : Stéphane Aubier,37 distinct words
# Retrieving (55/250) summary for : Anthony Bell,13 distinct words
# Retrieving (56/250) summary for : Hayao Miyazaki,194 distinct words
# Retrieving (57/250) summary for : Teddy Newton,63 distinct words
# Retrieving (58/250) summary for : Sergio Leone,48 distinct words
# Retrieving (59/250) summary for : Alex Garland,49 distinct words
# Retrieving (60/250) summary for : Travis Knight,18 distinct words
# Retrieving (61/250) summary for : Ciro Guerra,81 distinct words
# Retrieving (62/250) summary for : Benjamin Caron,94 distinct words
# Retrieving (63/250) summary for : Dan Gilroy,22 distinct words
# Retrieving (64/250) summary for : Gabriela Cowperthwaite,7 distinct words
# Retrieving (65/250) summary for : Sam Dunn,34 distinct words
# Retrieving (66/250) summary for : Martin Rosen,6 distinct words
# Retrieving (67/250) summary for : Lynne Ramsay,53 distinct words
# Retrieving (68/250) summary for : David Sandberg,17 distinct words
# Retrieving (69/250) summary for : Pif,6 distinct words
# Retrieving (70/250) summary for : Philip G. Atwell,87 distinct words
# Retrieving (71/250) summary for : Ruben Fleischer,58 distinct words
# Retrieving (72/250) summary for : George Scribner,13 distinct words
# Retrieving (73/250) summary for : Anton Corbijn,48 distinct words
# Retrieving (74/250) summary for : Jacques Rivette,187 distinct words
# Retrieving (75/250) summary for : Byron Howard,29 distinct words
# Retrieving (76/250) summary for : Lee Unkrich,72 distinct words
# Retrieving (77/250) summary for : Hiromasa Yonebayashi,33 distinct words
# Retrieving (78/250) summary for : Patrick Osborne,6 distinct words
# Retrieving (79/250) summary for : Jiang Wen,30 distinct words
# Retrieving (80/250) summary for : Colin Trevorrow,18 distinct words
# Retrieving (81/250) summary for : Stephen Daldry,32 distinct words
# Retrieving (82/250) summary for : Sebastian Junger,22 distinct words
# Retrieving (83/250) summary for : Daniel Scheinert,7 distinct words
# Retrieving (84/250) summary for : Stephen Gaghan,18 distinct words
# Retrieving (85/250) summary for : Tony Bancroft,21 distinct words
# Retrieving (86/250) summary for : Peter Avanzino,40 distinct words
# Retrieving (87/250) summary for : Joss Whedon,58 distinct words
# Retrieving (88/250) summary for : Genndy Tartakovsky,52 distinct words
# Retrieving (89/250) summary for : D.A. Pennebaker,30 distinct words
# Retrieving (90/250) summary for : Michel Hazanavicius,24 distinct words
# Retrieving (91/250) summary for : Xavier Dolan,40 distinct words
# Retrieving (92/250) summary for : Damien Chazelle,55 distinct words
# Retrieving (93/250) summary for : Shane Black,49 distinct words
# Retrieving (94/250) summary for : David Lynch,217 distinct words
# Retrieving (95/250) summary for : Lisanne Pajot,7 distinct words
# Retrieving (96/250) summary for : Charles Ferguson,18 distinct words
# Retrieving (97/250) summary for : Stephen Hillenburg,148 distinct words
# Retrieving (98/250) summary for : Spike Jonze,90 distinct words
# Retrieving (99/250) summary for : Allen Hughes,39 distinct words
# Retrieving (100/250) summary for : Christopher Nolan,109 distinct words
# Retrieving (101/250) summary for : Jeff Zimbalist,74 distinct words
# Retrieving (102/250) summary for : Adam Elliot,108 distinct words
# Retrieving (103/250) summary for : Rob Burnett,18 distinct words
# Retrieving (104/250) summary for : Charlie Siskel,7 distinct words
# Retrieving (105/250) summary for : László Nemes,28 distinct words
# Retrieving (106/250) summary for : Richard Curtis,90 distinct words
# Retrieving (107/250) summary for : Stan Lathan,22 distinct words
# Retrieving (108/250) summary for : Rocco Urbisci,38 distinct words
# Retrieving (109/250) summary for : Ethan Spaulding,37 distinct words
# Retrieving (110/250) summary for : Paolo Sorrentino,2 distinct words
# Retrieving (111/250) summary for : Scott Cooper,15 distinct words
# Retrieving (112/250) summary for : Alastair Fothergill,119 distinct words
# Retrieving (113/250) summary for : Don Hertzfeldt,136 distinct words
# Retrieving (114/250) summary for : Jean Cocteau,58 distinct words
# Retrieving (115/250) summary for : Shannon Hartman,7 distinct words
# Retrieving (116/250) summary for : Gabriele Mainetti,7 distinct words
# Retrieving (117/250) summary for : François Simard,7 distinct words
# Retrieving (118/250) summary for : Cary Fukunaga,31 distinct words
# Retrieving (119/250) summary for : Sydney Sibilia,7 distinct words
# Retrieving (120/250) summary for : Michel Ocelot,52 distinct words
# Retrieving (121/250) summary for : Giuseppe Tornatore,47 distinct words
# Retrieving (122/250) summary for : Kenji Kamiyama,60 distinct words
# Retrieving (123/250) summary for : Roger Allers,21 distinct words
# Retrieving (124/250) summary for : James Parrott,9 distinct words
# Retrieving (125/250) summary for : Bill Paxton,37 distinct words
# Retrieving (126/250) summary for : Mark Romanek,48 distinct words
# Retrieving (127/250) summary for : Gabriel Axel,14 distinct words
# Retrieving (128/250) summary for : Nick Park,76 distinct words
# Retrieving (129/250) summary for : James W. Horne,19 distinct words
# Retrieving (130/250) summary for : David Fincher,52 distinct words
# Retrieving (131/250) summary for : Jon M. Chu,45 distinct words
# Retrieving (132/250) summary for : Gary Hustwit,57 distinct words
# Retrieving (133/250) summary for : Eli Craig,31 distinct words
# Retrieving (134/250) summary for : Jorge R. Gutierrez,28 distinct words
# Retrieving (135/250) summary for : Tsuneo Kobayashi,14 distinct words
# Retrieving (136/250) summary for : Ryan Coogler,24 distinct words
# Retrieving (137/250) summary for : Bill Pohlad,22 distinct words
# Retrieving (138/250) summary for : Giulio Ricciarelli,5 distinct words
# Retrieving (139/250) summary for : Andrew Jarecki,42 distinct words
# Retrieving (140/250) summary for : Alexandre de La Patellière,7 distinct words
# Retrieving (141/250) summary for : Nitesh Tiwari,58 distinct words
# Retrieving (142/250) summary for : Merian C. Cooper,66 distinct words
# Retrieving (143/250) summary for : Toshiyuki Kubooka,16 distinct words
# Retrieving (144/250) summary for : Claude Barras,51 distinct words
# Retrieving (145/250) summary for : Asghar Farhadi,28 distinct words
# Retrieving (146/250) summary for : Moustapha Akkad,26 distinct words
# Retrieving (147/250) summary for : Ricky Gervais,130 distinct words
# Retrieving (148/250) summary for : Pete Docter,56 distinct words
# Retrieving (149/250) summary for : Angus MacLane,34 distinct words
# Retrieving (150/250) summary for : Charles Sturridge,6 distinct words
# Retrieving (151/250) summary for : Terry Zwigoff,11 distinct words
# Retrieving (152/250) summary for : Drew Barrymore,108 distinct words
# Retrieving (153/250) summary for : James Signorelli,18 distinct words
# Retrieving (154/250) summary for : Tom Ford,26 distinct words
# Retrieving (155/250) summary for : Deniz Gamze Ergüven,6 distinct words
# Retrieving (156/250) summary for : Vincent Paronnaud,62 distinct words
# Retrieving (157/250) summary for : Robert B. Weide,11 distinct words
# Retrieving (158/250) summary for : Peter Sohn,8 distinct words
# Retrieving (159/250) summary for : Shane Meadows,34 distinct words
# Retrieving (160/250) summary for : Laura Poitras,56 distinct words
# Retrieving (161/250) summary for : Bruce Gowers,61 distinct words
# Retrieving (162/250) summary for : Darren Grant,22 distinct words
# Retrieving (163/250) summary for : Amma Asante,12 distinct words
# Retrieving (164/250) summary for : Tom Hooper,129 distinct words
# Retrieving (165/250) summary for : Akira Kurosawa,139 distinct words
# Retrieving (166/250) summary for : Kevin Macdonald,26 distinct words
# Retrieving (167/250) summary for : Sylvain Chomet,5 distinct words
# Retrieving (168/250) summary for : Dean DeBlois,27 distinct words
# Retrieving (169/250) summary for : Barry Cook,23 distinct words
# Retrieving (170/250) summary for : Peter Jackson,113 distinct words
# Retrieving (171/250) summary for : Barry Jenkins,27 distinct words
# Retrieving (172/250) summary for : Kurt Kuenne,20 distinct words
# Retrieving (173/250) summary for : Jean-Pierre Jeunet,11 distinct words
# Retrieving (174/250) summary for : Philippe Garrel,16 distinct words
# Retrieving (175/250) summary for : Wes Anderson,59 distinct words
# Retrieving (176/250) summary for : Jonás Cuarón,32 distinct words
# Retrieving (177/250) summary for : Imtiaz Ali,7 distinct words
# Retrieving (178/250) summary for : Martin McDonagh,17 distinct words
# Retrieving (179/250) summary for : Chris Evans,44 distinct words
# Retrieving (180/250) summary for : Haifaa Al-Mansour,12 distinct words
# Retrieving (181/250) summary for : Shinichiro Watanabe,50 distinct words
# Retrieving (182/250) summary for : Babak Anvari,3 distinct words
# Retrieving (183/250) summary for : Dominic Polcino,41 distinct words
# Retrieving (184/250) summary for : Sebastian Schipper,5 distinct words
# Retrieving (185/250) summary for : Jorge Furtado,13 distinct words
# Retrieving (186/250) summary for : Floria Sigismondi,54 distinct words
# Retrieving (187/250) summary for : Taika Waititi,42 distinct words
# Retrieving (188/250) summary for : Heidi Ewing,71 distinct words
# Retrieving (189/250) summary for : Alexandre Astier,18 distinct words
# Retrieving (190/250) summary for : Jerry Rees,224 distinct words
# Retrieving (191/250) summary for : Mamoru Hosoda,3 distinct words
# Retrieving (192/250) summary for : Chris Buck,18 distinct words
# Retrieving (193/250) summary for : Kôji Morimoto,25 distinct words
# Retrieving (194/250) summary for : Andrei Tarkovsky,74 distinct words
# Retrieving (195/250) summary for : Matthew Vaughn,32 distinct words
# Retrieving (196/250) summary for : Hong Sang-soo,4 distinct words
# Retrieving (197/250) summary for : Zak Hilditch,7 distinct words
# Retrieving (198/250) summary for : Bong Joon-ho,61 distinct words
# Retrieving (199/250) summary for : Dwayne Carey-Hill,27 distinct words
# Retrieving (200/250) summary for : Julia Ducournau,31 distinct words
# Retrieving (201/250) summary for : Ava DuVernay,42 distinct words
# Retrieving (202/250) summary for : Mel Gibson,111 distinct words
# Retrieving (203/250) summary for : Maren Ade,20 distinct words
# Retrieving (204/250) summary for : Claudio Caligari,4 distinct words
# Retrieving (205/250) summary for : Brad Bird,103 distinct words
# Retrieving (206/250) summary for : Derek Jarman,11 distinct words
# Retrieving (207/250) summary for : Ron Clements,11 distinct words
# Retrieving (208/250) summary for : Julie Taymor,48 distinct words
# Retrieving (209/250) summary for : Jean-Pierre Melville,18 distinct words
# Retrieving (210/250) summary for : Angelina Jolie,171 distinct words
# Retrieving (211/250) summary for : Thomas Carter,53 distinct words
# Retrieving (212/250) summary for : Nicholas Hytner,21 distinct words
# Retrieving (213/250) summary for : François Girard,123 distinct words
# Retrieving (214/250) summary for : Jean-Marc Vallée,68 distinct words
# Retrieving (215/250) summary for : Louis C.K.,139 distinct words
# Retrieving (216/250) summary for : Robert Moore,63 distinct words
# Retrieving (217/250) summary for : Rob LaDuca,7 distinct words
# Retrieving (218/250) summary for : Damián Szifrón,16 distinct words
# Retrieving (219/250) summary for : Peter Brook,37 distinct words
# Retrieving (220/250) summary for : Hugo Gélin,4 distinct words
# Retrieving (221/250) summary for : Bob Gale,27 distinct words
# Retrieving (222/250) summary for : Liz W. Garcia,4 distinct words
# Retrieving (223/250) summary for : Ryan Fleck,16 distinct words
# Retrieving (224/250) summary for : Ol Parker,3 distinct words
# Retrieving (225/250) summary for : Tim McCanlies,15 distinct words
# Retrieving (226/250) summary for : Brin Hill,7 distinct words
# Retrieving (227/250) summary for : Léa Pool,27 distinct words
# Retrieving (228/250) summary for : Kazuhisa Takenôchi,7 distinct words
# Retrieving (229/250) summary for : Stella Meghie,49 distinct words
# Retrieving (230/250) summary for : James Mangold,30 distinct words
# Retrieving (231/250) summary for : Jia Zhangke,68 distinct words
# Retrieving (232/250) summary for : Hideaki Anno,48 distinct words
# Retrieving (233/250) summary for : Hiroshi Teshigahara,21 distinct words
# Retrieving (234/250) summary for : Ertem Eğilmez,19 distinct words
# Retrieving (235/250) summary for : F.W. Murnau,121 distinct words
# Retrieving (236/250) summary for : J.J. Abrams,89 distinct words
# Retrieving (237/250) summary for : Fisher Stevens,53 distinct words
# Retrieving (238/250) summary for : David Mallet,5 distinct words
# Retrieving (239/250) summary for : Wong Kar-wai,58 distinct words
# Retrieving (240/250) summary for : James Gunn,36 distinct words
# Retrieving (241/250) summary for : Douglas Mackinnon,58 distinct words
# Retrieving (242/250) summary for : Morgan Neville,95 distinct words
# Retrieving (243/250) summary for : Bennett Miller,14 distinct words
# Retrieving (244/250) summary for : Liz Garbus,55 distinct words
# Retrieving (245/250) summary for : Peter Joseph,27 distinct words
# Retrieving (246/250) summary for : Martin Zandvliet,5 distinct words
# Retrieving (247/250) summary for : Martin Scorsese,162 distinct words
# Retrieving (248/250) summary for : Sanjay Leela Bhansali,108 distinct words
# Retrieving (249/250) summary for : Tom Shankland,32 distinct words

# %%
df.describe()
# Out:
#             award     winning    american  television      writer    producer  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.004000    0.004000    0.004000    0.004000    0.004000    0.004000
# std      0.008057    0.019696    0.006758    0.009512    0.009715    0.006831
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.006369    0.000000    0.007194    0.000000    0.000000    0.010204
# max      0.057325    0.153846    0.064748    0.057143    0.050000    0.051020
#
#             among     credits  showrunner  co-creator     ...         goliyon  \
# count  250.000000  250.000000  250.000000  250.000000     ...      250.000000
# mean     0.004000    0.004000    0.004000    0.004000     ...        0.004000
# std      0.013975    0.025559    0.044631    0.036368     ...        0.063246
# min      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 25%      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 50%      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 75%      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# max      0.052632    0.166667    0.500000    0.500000     ...        1.000000
#
#        box-office  collections         kom     bajirao     mastani  \
# count  250.000000   250.000000  250.000000  250.000000  250.000000
# mean     0.004000     0.004000    0.004000    0.004000    0.004000
# std      0.063246     0.063246    0.063246    0.063246    0.063246
# min      0.000000     0.000000    0.000000    0.000000    0.000000
# 25%      0.000000     0.000000    0.000000    0.000000    0.000000
# 50%      0.000000     0.000000    0.000000    0.000000    0.000000
# 75%      0.000000     0.000000    0.000000    0.000000    0.000000
# max      1.000000     1.000000    1.000000    1.000000    1.000000
#
#              otto       fades      ripper        bait
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.004000    0.004000    0.004000    0.004000
# std      0.063246    0.063246    0.063246    0.063246
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 4088 columns]

# %%
#On vire tous les mots qui apparaissent une fois (probablement des titres de film)
serie = df.sum(axis=0)
for key in df:
    if serie[key]==1:
        df.drop(key,axis=1,inplace=True)
        print("dropped : "+key)
# Out:
# dropped : preschool
# dropped : clues
# dropped : kill
# dropped : darlings
# dropped : soccer
# dropped : bestseller
# dropped : audrey
# dropped : tautou
# dropped : renaudot
# dropped : donmar
# dropped : warehouse
# dropped : siegel
# dropped : boston
# dropped : legal
# dropped : surface
# dropped : childrens
# dropped : complicated
# dropped : dollar
# dropped : arm
# dropped : escape
# dropped : worst
# dropped : ...
# dropped : stuart
# dropped : synecdoche
# dropped : well-received
# dropped : celebrated
# dropped : sister
# dropped : oulaya
# dropped : paradise
# dropped : divines
# dropped : taylor
# dropped : moral
# dropped : orel
# dropped : phil
# dropped : nightwing
# dropped : jersey
# dropped : sign
# dropped : constitution
# dropped : speaker
# dropped : senate
# dropped : arrested
# dropped : treason
# dropped : connection
# dropped : aaron
# dropped : burr
# dropped : conspiracy
# dropped : recovered
# dropped : llc
# dropped : burbank
# dropped : wholly
# dropped : division
# dropped : feige
# dropped : reorganized
# dropped : marvel-character
# dropped : exceeded
# dropped : revenue
# dropped : multi-film
# dropped : incredible
# dropped : hulk
# dropped : releasing
# dropped : distribute
# dropped : conjunction
# dropped : within
# dropped : share
# dropped : continuity
# dropped : one-shots
# dropped : universidad
# dropped : del
# dropped : cine
# dropped : voluntad
# dropped : reloj
# dropped : plan
# dropped : rome
# dropped : ausente
# dropped : absent
# dropped : judging
# dropped : committee
# dropped : innovative
# dropped : sophisticated
# dropped : approach
# dropped : creates
# dropped : dynamism
# dropped : combination
# dropped : homoerotic
# dropped : desire
# dropped : suspense
# dropped : nscad
# dropped : bug
# dropped : wreck-it
# dropped : ralph
# dropped : supervisor
# dropped : reported
# dropped : shedd
# dropped : croatian-american
# dropped : n.y.h.c.
# dropped : length
# dropped : hardcore
# dropped : vhs
# dropped : halo
# dropped : two-dvd
# dropped : mommie
# dropped : jodorowsky
# dropped : telluride
# dropped : fest
# dropped : classics
# dropped : maintains
# dropped : rating
# dropped : rotten
# dropped : tomatoes
# dropped : investigate
# dropped : global
# dropped : places
# dropped : africa
# dropped : virunga
# dropped : helmets
# dropped : categories
# dropped : joanna
# dropped : grain
# dropped : creativity
# dropped : pencil
# dropped : schweppes
# dropped : finalist
# dropped : rave
# dropped : hindi
# dropped : munna
# dropped : bhai
# dropped : m.b.b.s
# dropped : lage
# dropped : raho
# dropped : munnabhai
# dropped : idiots
# dropped : hidden
# dropped : film-maker
# dropped : favourite
# dropped : power
# dropped : explore
# dropped : areas
# dropped : sociology
# dropped : psychology
# dropped : philosophy
# dropped : describes
# dropped : journalism
# dropped : expounded
# dropped : closely
# dropped : reporter
# dropped : jerome
# dropped : storylines
# dropped : aestheticization
# dropped : ensemble
# dropped : consisting
# dropped : lesser-known
# dropped : references
# dropped : soundtracks
# dropped : songs
# dropped : birthday
# dropped : basis
# dropped : reservoir
# dropped : boosted
# dropped : judged
# dropped : weekly
# dropped : scholars
# dropped : effort
# dropped : paid
# dropped : homage
# dropped : blaxploitation
# dropped : jackie
# dropped : rum
# dropped : traditions
# dropped : kung
# dropped : martial
# dropped : proof
# dropped : double
# dropped : rodriguez
# dropped : grindhouse
# dropped : long-postponed
# dropped : inglourious
# dropped : basterds
# dropped : tells
# dropped : alternate
# dropped : assassinate
# dropped : germany
# dropped : leadership
# dropped : django
# dropped : unchained
# dropped : antebellum
# dropped : eighth
# dropped : hateful
# dropped : roadshow
# dropped : halfway-point
# dropped : intermission
# dropped : bogdanovich
# dropped : anonymous
# dropped : england-based
# dropped : unverified
# dropped : subversive
# dropped : epigrams
# dropped : combine
# dropped : humour
# dropped : executed
# dropped : stenciling
# dropped : commentary
# dropped : bridges
# dropped : cities
# dropped : underground
# dropped : founding
# dropped : massive
# dropped : visible
# dropped : surfaces
# dropped : self-built
# dropped : physical
# dropped : photographs
# dropped : reproductions
# dropped : auctioneers
# dropped : attempt
# dropped : location
# dropped : problem
# dropped : removal
# dropped : hands
# dropped : bidder
# dropped : exit
# dropped : gift
# dropped : shop
# dropped : billed
# dropped : disaster
# dropped : webby
# dropped : captain
# dropped : greek-american
# dropped : geographic
# dropped : scuba-diver
# dropped : increasingly
# dropped : concerned
# dropped : bringing
# dropped : underwater
# dropped : stuntman
# dropped : wick
# dropped : leitch
# dropped : doubling
# dropped : fatal
# dropped : involving
# dropped : crow
# dropped : coordinator
# dropped : patrick
# dropped : troubled
# dropped : mentally
# dropped : shane
# dropped : meadows
# dropped : cinderella
# dropped : fuzz
# dropped : ultimatum
# dropped : macbeth
# dropped : cry
# dropped : owl
# dropped : blitz
# dropped : honour
# dropped : gifts
# dropped : prompted
# dropped : observer
# dropped : describe
# dropped : best-kept
# dropped : suspicions
# dropped : whicher
# dropped : put
# dropped : smile
# dropped : monkeys
# dropped : come
# dropped : evening
# dropped : standard
# dropped : thessaloniki
# dropped : seattle
# dropped : slums
# dropped : beverly
# dropped : hills
# dropped : savages
# dropped : keyboardist
# dropped : specializing
# dropped : time-lapse
# dropped : purely
# dropped : non-verbal
# dropped : non-narrative
# dropped : equipment
# dropped : imax
# dropped : site
# dropped : parts
# dropped : sith
# dropped : shoot
# dropped : eruption
# dropped : etna
# dropped : sicily
# dropped : volcanic
# dropped : mustafar
# dropped : samsara
# dropped : feel
# dropped : evolved
# dropped : technically
# dropped : philosophically
# dropped : ready
# dropped : delve
# dropped : even
# dropped : deeper
# dropped : barcelona
# dropped : spanish
# dropped : jaroslav
# dropped : prague
# dropped : czech
# dropped : geri
# dropped : originator
# dropped : mermaid
# dropped : prince
# dropped : revived
# dropped : emulated
# dropped : copied
# dropped : stray
# dropped : roaming
# dropped : apartment
# dropped : bought
# dropped : cartoons
# dropped : revive
# dropped : nightmare
# dropped : ned
# dropped : challenge
# dropped : musketeers
# dropped : chimps
# dropped : scrapped
# dropped : rideshare
# dropped : iphone
# dropped : buffalo
# dropped : niagara
# dropped : honolulu
# dropped : american-born
# dropped : copenhagen
# dropped : denmark
# dropped : marshall
# dropped : virgin
# dropped : castaway
# dropped : dictator
# dropped : playhouse
# dropped : auteurs
# dropped : hou
# dropped : hsiao-hsien
# dropped : tsai
# dropped : ming-liang
# dropped : film-makers
# dropped : fukuoka
# dropped : chikushino
# dropped : yokohama
# dropped : kamikaze
# dropped : confessions
# dropped : shortlist
# dropped : differences
# dropped : rest
# dropped : sapporo
# dropped : creators
# dropped : janica
# dropped : department
# dropped : musashino
# dropped : wanibuchi
# dropped : paranoia
# dropped : guitarist
# dropped : tsuyoshi
# dropped : kluzo
# dropped : remembered
# dropped : declared
# dropped : fan
# dropped : desiring
# dropped : adolphe
# dropped : osso
# dropped : french-language
# dropped : versions
# dropped : friendship
# dropped : jewish
# dropped : bedridden
# dropped : contracting
# dropped : tuberculosis
# dropped : recovering
# dropped : occupied
# dropped : german-owned
# dropped : corbeau
# dropped : harsh
# dropped : provincial
# dropped : result
# dropped : barred
# dropped : ban
# dropped : lifted
# dropped : reestablished
# dropped : quai
# dropped : des
# dropped : miquette
# dropped : gibson-amado
# dropped : serve
# dropped : source
# dropped : material
# dropped : remakes
# dropped : suffered
# dropped : depression
# dropped : illness
# dropped : views
# dropped : active
# dropped : unused
# dropped : greek
# dropped : surly
# dropped : open
# dropped : toonbox
# dropped : greenlit
# dropped : nutty
# dropped : micheal
# dropped : waukesha
# dropped : wisconsin
# dropped : right-handed
# dropped : career-high
# dropped : ranking
# dropped : katano
# dropped : osaka
# dropped : quick-change
# dropped : performer
# dropped : guinness
# dropped : quickest
# dropped : bestselling
# dropped : coming-of-age
# dropped : perks
# dropped : wallflower
# dropped : lerman
# dropped : watson
# dropped : ezra
# dropped : rent
# dropped : evan
# dropped : spiliotopoulos
# dropped : cbs
# dropped : jericho
# dropped : saloon
# dropped : kilkenny
# dropped : kells
# dropped : belgian
# dropped : panic
# dropped : renner
# dropped : ernest
# dropped : celestine
# dropped : magritte
# dropped : linebacker
# dropped : cardinals
# dropped : hepburn
# dropped : masterful
# dropped : storyteller
# dropped : maker
# dropped : in-between
# dropped : isao
# dropped : doggie
# dropped : gulliver
# dropped : travels
# dropped : beyond
# dropped : provided
# dropped : puss
# dropped : boots
# dropped : a-pro
# dropped : lupin
# dropped : nippon
# dropped : telecom
# dropped : cagliostro
# dropped : valley
# dropped : neighbor
# dropped : totoro
# dropped : porco
# dropped : rosso
# dropped : mononoke
# dropped : spirited
# dropped : away
# dropped : ponyo
# dropped : rises
# dropped : announced
# dropped : recurrence
# dropped : wholesomeness
# dropped : patterns
# dropped : importance
# dropped : craftsmanship
# dropped : difficulty
# dropped : maintaining
# dropped : pacifist
# dropped : ethic
# dropped : violent
# dropped : present
# dropped : antagonists
# dropped : redeeming
# dropped : qualities
# dropped : impact
# dropped : suggested
# dropped : praising
# dropped : depth
# dropped : artistry
# dropped : world-renowned
# dropped : jack-jack
# dropped : voices
# dropped : newsreel
# dropped : skinner
# dropped : 'steward
# dropped : robots
# dropped : chatter
# dropped : telephone
# dropped : mini
# dropped : toons
# dropped : untitled
# dropped : derek
# dropped : connolly
# dropped : inventor
# dropped : film-making
# dropped : juxtaposing
# dropped : extreme
# dropped : close-up
# dropped : sword
# dropped : sandal
# dropped : pompeii
# dropped : colossus
# dropped : rhodes
# dropped : clint
# dropped : eastwood
# dropped : fistful
# dropped : good
# dropped : ugly
# dropped : sucker
# dropped : medawar
# dropped : lauding
# dropped : generation
# dropped : dredd
# dropped : machina
# dropped : explored
# dropped : mankind
# dropped : artificial
# dropped : intelligence
# dropped : rapper
# dropped : laika
# dropped : kubo
# dropped : wandering
# dropped : journeys
# dropped : certain
# dropped : regard
# dropped : embrace
# dropped : serpent
# dropped : c.i.c.a.e
# dropped : odessa
# dropped : lima
# dropped : nominees
# dropped : dystopian
# dropped : detainee
# dropped : liney
# dropped : grant
# dropped : myers
# dropped : birds
# dropped : passage
# dropped : guajira
# dropped : something
# dropped : coetzee
# dropped : waiting
# dropped : barbarians
# dropped : rylance
# dropped : bafta-nominated
# dropped : factual
# dropped : paired
# dropped : derren
# dropped : one-hour
# dropped : heist
# dropped : bailey
# dropped : skins
# dropped : fat
# dropped : biopic
# dropped : leftbank
# dropped : tommy
# dropped : cooper
# dropped : wallander
# dropped : multi
# dropped : re-teamed
# dropped : branagh
# dropped : tale
# dropped : crown
# dropped : morgan
# dropped : claire
# dropped : foy
# dropped : matt
# dropped : lithgow
# dropped : bring
# dropped : christopher
# dropped : nominee
# dropped : steel
# dropped : legacy
# dropped : anthropologist
# dropped : heavy
# dropped : metal
# dropped : scot
# dropped : mcfadyen
# dropped : owns
# dropped : banger
# dropped : thesis
# dropped : guatemalan
# dropped : jews
# dropped : ratcatcher
# dropped : morvern
# dropped : callar
# dropped : need
# dropped : recurring
# dropped : grief
# dropped : aftermath
# dropped : low
# dropped : explicit
# dropped : exposition
# dropped : instead
# dropped : details
# dropped : worlds
# dropped : swedish
# dropped : no-budget
# dropped : online
# dropped : pseudonym
# dropped : pingtung
# dropped : airport
# dropped : iata
# dropped : code
# dropped : income
# dropped : misspelled
# dropped : helmed
# dropped : smoke
# dropped : row
# dropped : pooh
# dropped : wash
# dropped : xzibit
# dropped : damon
# dropped : johnson
# dropped : viola
# dropped : presents
# dropped : management
# dropped : turbo
# dropped : charged
# dropped : prelude
# dropped : bridging
# dropped : severance
# dropped : one-minute-movie
# dropped : nbc
# dropped : shield
# dropped : jet
# dropped : jason
# dropped : samuel
# dropped : zombieland
# dropped : minutes
# dropped : mixed
# dropped : venom
# dropped : brands
# dropped : cisco
# dropped : eurostar
# dropped : burger
# dropped : m.i.a.
# dropped : chains
# dropped : johannes
# dropped : gerrit
# dropped : van
# dropped : willenswaard
# dropped : handled
# dropped : promotion
# dropped : sleeve
# dropped : bands
# dropped : enjoy
# dropped : words
# dropped : nirvana
# dropped : heart-shaped
# dropped : viva
# dropped : curtis
# dropped : control
# dropped : commonly
# dropped : twenty-nine
# dropped : improvisation
# dropped : narratives
# dropped : cocteau
# dropped : frequenting
# dropped : langlois
# dropped : jean-luc
# dropped : rohmer
# dropped : claude
# dropped : members
# dropped : bazin
# dropped : admiration
# dropped : ford
# dropped : alfred
# dropped : hitchcock
# dropped : deeply
# dropped : articles
# dropped : admired
# dropped : peers
# dropped : aggressive
# dropped : writings
# dropped : article
# dropped : interviews
# dropped : coup
# dropped : berger
# dropped : belongs
# dropped : popularized
# dropped : fought
# dropped : censorship
# dropped : nun
# dropped : re-evaluated
# dropped : turmoil
# dropped : improvisational
# dropped : in-depth
# dropped : interview
# dropped : renoir
# dropped : groups
# dropped : allowing
# dropped : events
# dropped : unfold
# dropped : thirteen-hour
# dropped : rarely
# dropped : holy
# dropped : grail
# dropped : cinephiles
# dropped : incorporated
# dropped : better-regarded
# dropped : nervous
# dropped : breakdown
# dropped : slowed
# dropped : partnership
# dropped : martine
# dropped : marignac
# dropped : completing
# dropped : mountain
# dropped : revealed
# dropped : alzheimer
# dropped : disease
# dropped : private
# dropped : parolini
# dropped : manniez
# dropped : zootopia
# dropped : bear
# dropped : longtime
# dropped : nemo
# dropped : chagrin
# dropped : falls
# dropped : ohio
# dropped : youth
# dropped : cleveland
# dropped : joining
# dropped : laura
# dropped : hannah
# dropped : alice
# dropped : pickford
# dropped : distinguished
# dropped : recognizing
# dropped : vice-president
# dropped : editorial
# dropped : layout
# dropped : nonoichi
# dropped : ishikawa
# dropped : maro
# dropped : arrietty
# dropped : marnie
# dropped : kanazawa
# dropped : majored
# dropped : grouped
# dropped : gong
# dropped : yimou
# dropped : sorghum
# dropped : baze
# dropped : malbus
# dropped : anthology
# dropped : rogue
# dropped : older
# dropped : safety
# dropped : guaranteed
# dropped : blockbuster
# dropped : jurassic
# dropped : and/or
# dropped : elliot
# dropped : reader
# dropped : extremely
# dropped : loud
# dropped : incredibly
# dropped : best-selling
# dropped : perfect
# dropped : storm
# dropped : chronicle
# dropped : afghanistan
# dropped : restrepo
# dropped : korengal
# dropped : soderbergh
# dropped : traffic
# dropped : syriana
# dropped : christian
# dropped : toonacious
# dropped : serves
# dropped : dividenine
# dropped : rough
# dropped : draft
# dropped : glendale/burbank
# dropped : duckman
# dropped : thornberrys
# dropped : saved
# dropped : resides
# dropped : kids
# dropped : mutant
# dropped : bellwether
# dropped : buffy
# dropped : slayer
# dropped : dollhouse
# dropped : agents
# dropped : s.h.i.e.l.d
# dropped : continuation
# dropped : serenity
# dropped : mini-series
# dropped : horrible
# dropped : sing-along
# dropped : cabin
# dropped : woods
# dropped : ultron
# dropped : borisovich
# dropped : laboratory
# dropped : clone
# dropped : sym-bionic
# dropped : transylvania
# dropped : additionally
# dropped : pivotal
# dropped : powerpuff
# dropped : tiny
# dropped : toon
# dropped : normally
# dropped : transliterated
# dropped : gennadiy
# dropped : spelling
# dropped : alan
# dropped : pioneers
# dropped : performing
# dropped : politics
# dropped : subjects
# dropped : arguably
# dropped : pre-eminent
# dropped : chronicler
# dropped : sixties
# dropped : a.za.na.vi.sjys
# dropped : spy
# dropped : cairo
# dropped : nest
# dropped : spies
# dropped : arthouse
# dropped : mommy
# dropped : sayre
# dropped : madeline
# dropped : park
# dropped : bench
# dropped : whiplash
# dropped : record-tying
# dropped : fourteen
# dropped : scout
# dropped : goodnight
# dropped : hawkins
# dropped : write
# dropped : nice
# dropped : guys
# dropped : installment
# dropped : adaption
# dropped : doc
# dropped : ranks
# dropped : twelfth
# dropped : allmovie
# dropped : renaissance
# dropped : labelled
# dropped : middle-class
# dropped : missoula
# dropped : study
# dropped : philadelphia
# dropped : transition
# dropped : midnight
# dropped : deformed
# dropped : merrick
# dropped : elephant
# dropped : laurentiis
# dropped : proceeded
# dropped : science-fiction
# dropped : proved
# dropped : failure
# dropped : stirred
# dropped : prequel
# dropped : straight
# dropped : towards
# dropped : operated
# dropped : non-linear
# dropped : structures
# dropped : fragmented
# dropped : meanwhile
# dropped : embraced
# dropped : web-based
# dropped : dumbland
# dropped : rabbits
# dropped : reunited
# dropped : showtime
# dropped : endeavours
# dropped : clown
# dropped : variety
# dropped : transcendental
# dropped : meditation
# dropped : schools
# dropped : catching
# dropped : fish
# dropped : advertisements
# dropped : dior
# dropped : promotional
# dropped : lady
# dropped : shanghai
# dropped : legion
# dropped : officier
# dropped : respective
# dropped : stanford
# dropped : federation
# dropped : frederick
# dropped : vermeer
# dropped : technologies
# dropped : architect
# dropped : mcdannell
# dropped : cartoonist
# dropped : biologist
# dropped : longest-running
# dropped : highest-rated
# dropped : lawton
# dropped : oklahoma
# dropped : raised
# dropped : anaheim
# dropped : fascinated
# dropped : ocean
# dropped : instructing
# dropped : biology
# dropped : orange
# dropped : county
# dropped : informative
# dropped : tide-pool
# dropped : educate
# dropped : students
# dropped : leaving
# dropped : enrolled
# dropped : offered
# dropped : rocko
# dropped : green
# dropped : beret
# dropped : wormholes
# dropped : finale
# dropped : resigned
# dropped : blvd.
# dropped : usa
# dropped : sponge
# dropped : accolade
# dropped : heal
# dropped : bay
# dropped : elevating
# dropped : cartoonists
# dropped : despite
# dropped : controversies
# dropped : speculation
# dropped : sexual
# dropped : orientation
# dropped : lawsuit
# dropped : filed
# dropped : diagnosed
# dropped : amyotrophic
# dropped : lateral
# dropped : sclerosis
# dropped : als
# dropped : stated
# dropped : continue
# dropped : spiegel
# dropped : kaufman
# dropped : daft
# dropped : punk
# dropped : fatboy
# dropped : slim
# dropped : weezer
# dropped : beastie
# dropped : kanye
# dropped : jackass
# dropped : inc..
# dropped : skateboard
# dropped : skateboards
# dropped : riders
# dropped : rick
# dropped : howard
# dropped : mike
# dropped : cunningham
# dropped : michel
# dropped : gondry
# dropped : palm
# dropped : brownsburg
# dropped : herald
# dropped : tribune
# dropped : join
# dropped : newspaper
# dropped : sunday
# dropped : leisure
# dropped : sarasota
# dropped : florida
# dropped : british-american
# dropped : considerable
# dropped : memento
# dropped : opportunity
# dropped : insomnia
# dropped : prestige
# dropped : interstellar
# dropped : dunkirk
# dropped : grossed
# dropped : jonathan
# dropped : syncopy
# dropped : rooted
# dropped : philosophical
# dropped : sociological
# dropped : ethical
# dropped : exploring
# dropped : human
# dropped : morality
# dropped : causality
# dropped : construction
# dropped : malleable
# dropped : memory
# dropped : permeated
# dropped : materialistic
# dropped : perspectives
# dropped : labyrinthine
# dropped : storytelling
# dropped : practical
# dropped : analogous
# dropped : relationships
# dropped : elements
# dropped : leib
# dropped : nettler
# dropped : northampton
# dropped : massachusetts
# dropped : favela
# dropped : rising
# dropped : escobars
# dropped : youngstown
# dropped : pele
# dropped : scribe
# dropped : eminent
# dropped : names
# dropped : quincy
# dropped : shakira
# dropped : jesse
# dropped : arnold
# dropped : schwarzenegger
# dropped : mick
# dropped : jagger
# dropped : javier
# dropped : bardem
# dropped : russell
# dropped : simmons
# dropped : campbell
# dropped : aishwarya
# dropped : rai
# dropped : amitabh
# dropped : bachchan
# dropped : rise
# dropped : berwick
# dropped : collectively
# dropped : participated
# dropped : harvie
# dropped : krumpet
# dropped : annecy
# dropped : cristals
# dropped : bittersweet
# dropped : engage
# dropped : exclusively
# dropped : loosely
# dropped : clayography
# dropped : clay
# dropped : biography
# dropped : 'in-camera
# dropped : techniques
# dropped : means
# dropped : 'real
# dropped : miniature
# dropped : handcrafted
# dropped : object
# dropped : additions
# dropped : generated
# dropped : enhance
# dropped : clayographies
# dropped : practices
# dropped : adhere
# dropped : methodology
# dropped : philip
# dropped : seymour
# dropped : hoffman
# dropped : toni
# dropped : collette
# dropped : eric
# dropped : bana
# dropped : mcinnes
# dropped : barry
# dropped : humphries
# dropped : flaus
# dropped : voting
# dropped : achiever
# dropped : defensive
# dropped : jeles
# dropped : whalley
# dropped : anthony
# dropped : britain
# dropped : weddings
# dropped : funeral
# dropped : bridget
# dropped : notting
# dropped : actually
# dropped : sitcoms
# dropped : blackadder
# dropped : bean
# dropped : vicar
# dropped : dibley
# dropped : charity
# dropped : lenny
# dropped : fellowship
# dropped : give
# dropped : britannia
# dropped : charitable
# dropped : telegraph
# dropped : husbands
# dropped : dave
# dropped : chappelle
# dropped : spin
# dropped : streaming
# dropped : dancer
# dropped : calling
# dropped : entitled
# dropped : blankfield
# dropped : replacing
# dropped : steve
# dropped : tomlin
# dropped : sold
# dropped : airbender
# dropped : held
# dropped : positions
# dropped : concluded
# dropped : warner
# dropped : bros
# dropped : thundercats
# dropped : reboot
# dropped : korra
# dropped : assault
# dropped : arkham
# dropped : chef
# dropped : papillon
# dropped : restaurant
# dropped : jose
# dropped : orley
# dropped : farm
# dropped : harrow
# dropped : zoology
# dropped : cuthbert
# dropped : durham
# dropped : okavango
# dropped : wildlife
# dropped : trials
# dropped : appointed
# dropped : tenure
# dropped : geographical
# dropped : cherry
# dropped : kearton
# dropped : medal
# dropped : stood
# dropped : concentrate
# dropped : multi-award-winning
# dropped : completed
# dropped : abyss
# dropped : clean
# dropped : energy
# dropped : bmw
# dropped : signed
# dropped : multi-picture
# dropped : newly
# dropped : spends
# dropped : months
# dropped : sabbatical
# dropped : african
# dropped : cats
# dropped : bears
# dropped : chimpanzee
# dropped : scholey
# dropped : linfield
# dropped : melinda
# dropped : sons
# dropped : hamish
# dropped : two-time
# dropped : award-nominated
# dropped : meaning
# dropped : rejected
# dropped : record
# dropped : vital
# dropped : expressive
# dropped : cavalier
# dropped : either
# dropped : phenomenon
# dropped : forward
# dropped : individual
# dropped : animators
# dropped : independently
# dropped : attracts
# dropped : kind
# dropped : fanatical
# dropped : support
# dropped : crowds
# dropped : usually
# dropped : combined
# dropped : proud
# dropped : seamless
# dropped : autumn
# dropped : l.a.
# dropped : runner-up
# dropped : annual
# dropped : indiewire
# dropped : review
# dropped : supports
# dropped : self-distribution
# dropped : ticket
# dropped : dvds
# dropped : broadcasts
# dropped : refused
# dropped : austin
# dropped : continuous
# dropped : maurice
# dropped : enfants
# dropped : orpheus
# dropped : associates
# dropped : lovers
# dropped : pablo
# dropped : gertrude
# dropped : stein
# dropped : marais
# dropped : bernstein
# dropped : yul
# dropped : brynner
# dropped : marlene
# dropped : dietrich
# dropped : coco
# dropped : chanel
# dropped : satie
# dropped : albert
# dropped : gleizes
# dropped : igor
# dropped : laurencin
# dropped : piaf
# dropped : panama
# dropped : colette
# dropped : genet
# dropped : raymond
# dropped : radiguet
# dropped : joji
# dropped : sin
# dropped : nombre
# dropped : jane
# dropped : eyre
# dropped : detective
# dropped : beasts
# dropped : nation
# dropped : programs
# dropped : formerly
# dropped : kirikou
# dropped : sorceress
# dropped : already
# dropped : d'honneur
# dropped : varda
# dropped : commandeur
# dropped : animafest
# dropped : zagreb
# dropped : probably
# dropped : nuovo
# dropped : paradiso
# dropped : campaigns
# dropped : dolce
# dropped : long-standing
# dropped : ennio
# dropped : morricone
# dropped : composed
# dropped : negrin
# dropped : saitama
# dropped : enterprise
# dropped : patlabor
# dropped : solid
# dropped : oshii
# dropped : contributing
# dropped : minipato
# dropped : eden
# dropped : east
# dropped : charley
# dropped : chase
# dropped : terminator
# dropped : weird
# dropped : aliens
# dropped : tombstone
# dropped : lies
# dropped : apollo
# dropped : twister
# dropped : titanic
# dropped : hatfields
# dropped : mccoys
# dropped : photo
# dropped : inch
# dropped : nails
# dropped : chili
# dropped : peppers
# dropped : bedtime
# dropped : madonna
# dropped : janet
# dropped : form
# dropped : better
# dropped : babette
# dropped : feast
# dropped : wulstan
# dropped : shaun
# dropped : sheep
# dropped : creature
# dropped : comforts
# dropped : wrong
# dropped : trousers
# dropped : shave
# dropped : curse
# dropped : were-rabbit
# dropped : loaf
# dropped : run
# dropped : stop
# dropped : wesley
# dropped : sidney
# dropped : olcott
# dropped : kalem
# dropped : leo
# dropped : curious
# dropped : button
# dropped : satire
# dropped : tattoo
# dropped : instrumental
# dropped : creation
# dropped : bieber
# dropped : hasbro
# dropped : jem
# dropped : holograms
# dropped : g.i
# dropped : joe
# dropped : retaliation
# dropped : cinema-television
# dropped : grace
# dropped : dore
# dropped : schary
# dropped : anti-defamation
# dropped : nicholson
# dropped : honoree
# dropped : ifp/west
# dropped : involve
# dropped : examines
# dropped : trends
# dropped : euro-american
# dropped : typography
# dropped : industrial
# dropped : architecture
# dropped : urban
# dropped : planning
# dropped : dwell
# dropped : taking
# dropped : closer
# dropped : take
# dropped : granted
# dropped : changing
# dropped : think
# dropped : whether
# dropped : type
# dropped : salon.com
# dropped : sean
# dropped : anderson
# dropped : plexifilm
# dropped : truer
# dropped : helvetica
# dropped : matthew
# dropped : tucker
# dropped : dale
# dropped : lilly
# dropped : award-
# dropped : tigre
# dropped : manny
# dropped : rivera
# dropped : kanagawa
# dropped : affiliated
# dropped : pierrot
# dropped : kingdoms
# dropped : kyle
# dropped : fruitvale
# dropped : station
# dropped : seventh
# dropped : rocky
# dropped : creed
# dropped : eloise
# dropped : o'rourke
# dropped : financier
# dropped : carl
# dropped : twins
# dropped : jim
# dropped : milan
# dropped : italian-german
# dropped : entrepreneur
# dropped : emmy-winning
# dropped : jinx
# dropped : deaths
# dropped : arrest
# dropped : imprisonment
# dropped : capturing
# dropped : friedmans
# dropped : eighteen
# dropped : moviefone
# dropped : knowme
# dropped : ios
# dropped : platform
# dropped : chillar
# dropped : bhoothnath
# dropped : returns
# dropped : scripted
# dropped : dangal
# dropped : beijing
# dropped : brics
# dropped : fifth
# dropped : non-english
# dropped : collected
# dropped : highest-grossers
# dropped : telstra
# dropped : choice
# dropped : caldwell
# dropped : polish
# dropped : officer
# dropped : adventurer
# dropped : squadron
# dropped : prisoner
# dropped : start
# dropped : explorers
# dropped : documenting
# dropped : board
# dropped : pan
# dropped : airways
# dropped : always
# dropped : priority
# dropped : rko
# dropped : co-inventor
# dropped : cinerama
# dropped : projection
# dropped : robo
# dropped : ova
# dropped : lunar
# dropped : idolm
# dropped : ster
# dropped : swiss
# dropped : sierre
# dropped : illustration
# dropped : emile
# dropped : cohl
# dropped : ecal
# dropped : cantonale
# dropped : lausanne
# dropped : freelance
# dropped : ravioli
# dropped : courgette
# dropped : oficial
# dropped : iranian
# dropped : separation
# dropped : syrian
# dropped : halloween
# dropped : mohammad
# dropped : messenger
# dropped : daughter
# dropped : rima
# dropped : monla
# dropped : amman
# dropped : bombings
# dropped : dene
# dropped : initially
# dropped : pop
# dropped : seona
# dropped : dancing
# dropped : suede
# dropped : o'clock
# dropped : greater
# dropped : andy
# dropped : millman
# dropped : reprised
# dropped : muppets
# dropped : correspondents
# dropped : performed
# dropped : flanimals
# dropped : karl
# dropped : podcast
# dropped : spawned
# dropped : spin-offs
# dropped : hosted
# dropped : voted
# dropped : stand-ups
# dropped : updated
# dropped : hans
# dropped : bloomington
# dropped : collaborator
# dropped : universally
# dropped : thus
# dropped : hochi
# dropped : geeky
# dropped : kid
# dropped : likes
# dropped : draw
# dropped : burn-e
# dropped : terror
# dropped : dory
# dropped : enthusiast
# dropped : cubedudes
# dropped : official
# dropped : deals
# dropped : misfits
# dropped : antiheroes
# dropped : alienation
# dropped : blythe
# dropped : model
# dropped : granddaughter
# dropped : soon
# dropped : transitioned
# dropped : altered
# dropped : e.t
# dropped : extra-terrestrial
# dropped : turbulent
# dropped : publicized
# dropped : drug
# dropped : alcohol
# dropped : abuse
# dropped : stints
# dropped : rehab
# dropped : autobiography
# dropped : poison
# dropped : ivy
# dropped : scream
# dropped : co-starred
# dropped : sandler
# dropped : wedding
# dropped : dates
# dropped : blended
# dropped : nancy
# dropped : juvonen
# dropped : joint
# dropped : flower
# dropped : kissed
# dropped : donnie
# dropped : darko
# dropped : whip
# dropped : lyrics
# dropped : edie
# dropped : grey
# dropped : gardens
# dropped : timothy
# dropped : olyphant
# dropped : clarita
# dropped : diet
# dropped : segment
# dropped : carlyle
# dropped : launched
# dropped : eponymous
# dropped : luxury
# dropped : brand
# dropped : yves
# dropped : saint
# dropped : laurent
# dropped : nocturnal
# dropped : turkish-french
# dropped : mustang
# dropped : rochelle
# dropped : comprise
# dropped : negra
# dropped : monsieur
# dropped : ferraille
# dropped : pat
# dropped : boon
# dropped : welcome
# dropped : smart
# dropped : monkey
# dropped : l'art
# dropped : mouscaille
# dropped : pinaillage
# dropped : pinocchio
# dropped : flip
# dropped : flopi
# dropped : trust
# dropped : aut
# dropped : wizz
# dropped : cowriting
# dropped : codirecting
# dropped : marjane
# dropped : satrapi
# dropped : persepolis
# dropped : curb
# dropped : enthusiasm
# dropped : england
# dropped : somers
# dropped : donk
# dropped : scor-zay-zee
# dropped : roses
# dropped : citizenfour
# dropped : snowden
# dropped : polk
# dropped : security
# dropped : disclosures
# dropped : reporting
# dropped : greenwald
# dropped : ewen
# dropped : macaskill
# dropped : barton
# dropped : gellman
# dropped : pulitzer
# dropped : jointly
# dropped : macdowell
# dropped : colony
# dropped : initial
# dropped : supporters
# dropped : freedom
# dropped : press
# dropped : large-scale
# dropped : queen
# dropped : bohemian
# dropped : relocation
# dropped : idol
# dropped : billboard
# dropped : inaugural
# dropped : memorial
# dropped : jacksons
# dropped : stones
# dropped : mccartney
# dropped : rod
# dropped : britney
# dropped : spears
# dropped : eighty
# dropped : tyler
# dropped : happen
# dropped : winstead
# dropped : mbe
# dropped : teenager
# dropped : painted
# dropped : faces
# dropped : oxford
# dropped : quayside
# dropped : byker
# dropped : grove
# dropped : eastenders
# dropped : climate
# dropped : deronda
# dropped : helm
# dropped : revival
# dropped : itv
# dropped : dust
# dropped : hilary
# dropped : swank
# dropped : chiwetel
# dropped : ejiofor
# dropped : pictures/hbo
# dropped : seven-part
# dropped : damned
# dropped : fact-based
# dropped : brian
# dropped : clough
# dropped : sheen
# dropped : saw
# dropped : colin
# dropped : firth
# dropped : all-star
# dropped : hugh
# dropped : jackman
# dropped : craft
# dropped : entered
# dropped : stint
# dropped : sanshiro
# dropped : sugata
# dropped : judo
# dropped : drunken
# dropped : toshiro
# dropped : mifune
# dropped : cemented
# dropped : collaborate
# dropped : surprise
# dropped : winner
# dropped : markets
# dropped : products
# dropped : approximately
# dropped : ikiru
# dropped : yojimbo
# dropped : much
# dropped : epics
# dropped : kagemusha
# dropped : abroad
# dropped : accepted
# dropped : posthumously
# dropped : asianweek
# dropped : cnn
# dropped : prominently
# dropped : improvement
# dropped : past
# dropped : retrospectives
# dropped : studies
# dropped : biographies
# dropped : print
# dropped : releases
# dropped : consumer
# dropped : formats
# dropped : bishop
# dropped : archbishop
# dropped : dc-based
# dropped : evolutionary
# dropped : dreamworks
# dropped : documentary/music
# dropped : heima
# dropped : bancroft
# dropped : mulan
# dropped : sarah
# dropped : walking
# dropped : dinosaurs
# dropped : nightingale
# dropped : onz
# dropped : knzm
# dropped : rings
# dropped : hobbit
# dropped : novels
# dropped : tolkien
# dropped : lauded
# dropped : mockumentary
# dropped : forgotten
# dropped : frighteners
# dropped : lovely
# dropped : bones
# dropped : district
# dropped : tintin
# dropped : unicorn
# dropped : memphis
# dropped : taste
# dropped : feebles
# dropped : filming
# dropped : zombie
# dropped : braindead
# dropped : fran
# dropped : saturn
# dropped : amongst
# dropped : wingnut
# dropped : regular
# dropped : co-writers
# dropped : philippa
# dropped : boyens
# dropped : knighted
# dropped : anand
# dropped : satyanand
# dropped : governor-general
# dropped : wellington
# dropped : medicine
# dropped : melancholy
# dropped : moonlight
# dropped : dozens
# dropped : accolades
# dropped : co-writer
# dropped : tarell
# dropped : alvin
# dropped : mccraney
# dropped : rent-a-person
# dropped : validation
# dropped : dear
# dropped : zachary
# dropped : letter
# dropped : delicatessen
# dropped : resurrection
# dropped : wales
# dropped : empirical
# dropped : consistent
# dropped : award-winner
# dropped : alfonso
# dropped : vassar
# dropped : gravity
# dropped : uncle
# dropped : carlos
# dropped : credit
# dropped : cameo
# dropped : con
# dropped : pareja
# dropped : test
# dropped : dual
# dropped : citizenship
# dropped : playwrights
# dropped : welsh
# dropped : presenter
# dropped : labour
# dropped : co-operative
# dropped : tally
# dropped : outlaw
# dropped : chaplain
# dropped : psychologist
# dropped : leith
# dropped : biotech
# dropped : ugandan
# dropped : vocalist
# dropped : arabian
# dropped : best-known
# dropped : kyoto
# dropped : creations
# dropped : blends
# dropped : noir
# dropped : jazz/blues
# dropped : sets
# dropped : entire
# dropped : champloo
# dropped : unites
# dropped : cultures
# dropped : okinawa
# dropped : chanbara
# dropped : british-iranian
# dropped : lovesick
# dropped : fool
# dropped : funnyordie
# dropped : exhibit
# dropped : harmonquest
# dropped : hybrid
# dropped : animates
# dropped : tabletop
# dropped : rpg
# dropped : exploits
# dropped : celebrity
# dropped : hanover
# dropped : porto
# dropped : alegre
# dropped : grande
# dropped : sul
# dropped : brazilian
# dropped : flowers
# dropped : italian-canadian
# dropped : runaways
# dropped : kristen
# dropped : dakota
# dropped : fanning
# dropped : timberlake
# dropped : rihanna
# dropped : stripes
# dropped : bowie
# dropped : pink
# dropped : manson
# dropped : katy
# dropped : cure
# dropped : christina
# dropped : aguilera
# dropped : ellie
# dropped : goulding
# dropped : fiona
# dropped : apple
# dropped : muse
# dropped : interpol
# dropped : leonard
# dropped : weather
# dropped : mac
# dropped : target
# dropped : samsung
# dropped : absolut
# dropped : vodka
# dropped : navy
# dropped : motorola
# dropped : adidas
# dropped : thierry
# dropped : mugler
# dropped : cars
# dropped : wilderpeople
# dropped : thor
# dropped : ragnarok
# dropped : rachel
# dropped : grady
# dropped : loki
# dropped : camp
# dropped : heart-rending
# dropped : light
# dropped : abortion
# dropped : detropia
# dropped : poetic
# dropped : eye
# dropped : nonfiction
# dropped : news
# dropped : norman
# dropped : lear
# dropped : selection
# dropped : masters
# dropped : freakonomics
# dropped : mohammed
# dropped : hussein
# dropped : humorist
# dropped : kaamelott
# dropped : supervised
# dropped : tron
# dropped : sculptor
# dropped : trained
# dropped : taught
# dropped : hound
# dropped : supervisors
# dropped : cutting-edge
# dropped : adapting
# dropped : resulting
# dropped : teamed
# dropped : calarts
# dropped : alum
# dropped : co-write
# dropped : featurettes
# dropped : doom
# dropped : simon-penned
# dropped : marrying
# dropped : jam
# dropped : neverland
# dropped : cronkite
# dropped : disneyland
# dropped : educational
# dropped : tourist
# dropped : hell
# dropped : backstage
# dropped : leiva
# dropped : seventy-five
# dropped : percent
# dropped : storyboarded
# dropped : weeks
# dropped : recording
# dropped : mgm
# dropped : switched
# dropped : chiefs
# dropped : tentatively
# dropped : record-setting
# dropped : multimedia
# dropped : parks
# dropped : dangerous
# dropped : sequences
# dropped : cranium
# dropped : command
# dropped : epcot
# dropped : spectacular
# dropped : roller
# dropped : coaster
# dropped : extra-terrorestrial
# dropped : encounter
# dropped : magic
# dropped : cinemagique
# dropped : pre-ride
# dropped : ride
# dropped : rand
# dropped : repairman
# dropped : financed
# dropped : interscope
# dropped : futuristic
# dropped : expected
# dropped : showcase
# dropped : emerging
# dropped : casting
# dropped : storyboarding
# dropped : eventually
# dropped : players
# dropped : actress/writer
# dropped : deanna
# dropped : appearance
# dropped : northridge
# dropped : discuss
# dropped : full-time
# dropped : brain
# dropped : casey
# dropped : tarzan
# dropped : surf
# dropped : pocahontas
# dropped : shorts
# dropped : carnival
# dropped : animatrix
# dropped : hunter
# dropped : fist
# dropped : arsenyevich
# dropped : ipa
# dropped : theorist
# dropped : ivan
# dropped : solaris
# dropped : union
# dropped : nostalghia
# dropped : sacrifice
# dropped : italy
# dropped : sweden
# dropped : structure
# dropped : distinctly
# dropped : authored
# dropped : spiritual
# dropped : metaphysical
# dropped : contribution
# dropped : done
# dropped : tarkovskian
# dropped : ingmar
# dropped : bergman
# dropped : invented
# dropped : captures
# dropped : reflection
# dropped : vere
# dropped : drummond
# dropped : lock
# dropped : stock
# dropped : smoking
# dropped : barrels
# dropped : snatch
# dropped : layer
# dropped : cake
# dropped : stardust
# dropped : kick-ass
# dropped : class
# dropped : joon
# dropped : hangul
# dropped : hits
# dropped : memories
# dropped : true-life
# dropped : host
# dropped : english-language
# dropped : snowpiercer
# dropped : korean-american
# dropped : insiders
# dropped : tae-il
# dropped : word
# dropped : filled
# dropped : humor
# dropped : sudden
# dropped : shifts
# dropped : central
# dropped : susie
# dropped : dietter
# dropped : obsoletely
# dropped : napoleon
# dropped : junior
# dropped : petit
# dropped : rail
# dropped : torinofilmlab
# dropped : framework
# dropped : sutherland
# dropped : marketer
# dropped : distributor
# dropped : nowhere
# dropped : african-american
# dropped : wrinkle
# dropped : reportedly
# dropped : exceeding
# dropped : size
# dropped : colmcille
# dropped : gerard
# dropped : peekskill
# dropped : sydney
# dropped : riggs
# dropped : buddy
# dropped : rockatansky
# dropped : post-apocalyptic
# dropped : icon
# dropped : atom
# dropped : egoyan
# dropped : weir
# dropped : leads
# dropped : gallipoli
# dropped : earn
# dropped : serious
# dropped : versatile
# dropped : braveheart
# dropped : biblical
# dropped : passion
# dropped : notice
# dropped : action-adventure
# dropped : apocalypto
# dropped : mesoamerica
# dropped : hacksaw
# dropped : ridge
# dropped : mixing
# dropped : ludwigsburg
# dropped : janine
# dropped : jackowski
# dropped : jonas
# dropped : dornbach
# dropped : komplizen
# dropped : milt
# dropped : kahl
# dropped : legendary
# dropped : earliest
# dropped : classes
# dropped : batteries
# dropped : fared
# dropped : poorly
# dropped : rejoined
# dropped : place
# dropped : protocol
# dropped : tomorrowland
# dropped : clooney
# dropped : elworthy
# dropped : diarist
# dropped : gardener
# dropped : francis
# dropped : musker
# dropped : desk
# dropped : vision
# dropped : courage
# dropped : athena
# dropped : barnard
# dropped : off-broadway
# dropped : midsummer
# dropped : grumbach
# dropped : resistance
# dropped : nom
# dropped : guerre
# dropped : herman
# dropped : joh-lee
# dropped : highest-paid
# dropped : jon
# dropped : lookin
# dropped : earnest
# dropped : decade
# dropped : cyborg
# dropped : cable
# dropped : gia
# dropped : heroine
# dropped : tomb
# dropped : raider
# dropped : action-star
# dropped : mrs.
# dropped : salt
# dropped : mighty
# dropped : changeling
# dropped : expanded
# dropped : wartime
# dropped : honey
# dropped : unbroken
# dropped : maleficent
# dropped : hersholt
# dropped : damehood
# dropped : dcmg
# dropped : promotes
# dropped : conservation
# dropped : rights
# dropped : advocacy
# dropped : behalf
# dropped : envoy
# dropped : nations
# dropped : commissioner
# dropped : unhcr
# dropped : outlets
# dropped : wide
# dropped : publicity
# dropped : divorced
# dropped : jonny
# dropped : bob
# dropped : thornton
# dropped : separated
# dropped : husband
# dropped : brad
# dropped : fethard
# dropped : trim
# dropped : hillsborough
# dropped : dungarvan
# dropped : kingston
# dropped : parliament
# dropped : sinn
# dropped : ngaedhael/fianna
# dropped : minister
# dropped : english-born
# dropped : puritan
# dropped : superintendent
# dropped : marlborough
# dropped : reckless
# dropped : clerk
# dropped : military
# dropped : franklin
# dropped : soldier
# dropped : nevile
# dropped : railways
# dropped : thellusson
# dropped : protestant
# dropped : clergyman
# dropped : saigon
# dropped : guvnors
# dropped : montreal
# dropped : cargo
# dropped : thirty
# dropped : vignettes
# dropped : piano
# dropped : prodigy
# dropped : follows
# dropped : ownership
# dropped : centuries
# dropped : jutra
# dropped : symphony
# dropped : psalms
# dropped : oedipus
# dropped : rex
# dropped : novencento
# dropped : kafka
# dropped : trial
# dropped : serge
# dropped : lamothe
# dropped : centre
# dropped : ottawa
# dropped : oratorio
# dropped : brooklyn
# dropped : siegfried
# dropped : lindbergh
# dropped : flight
# dropped : deadly
# dropped : sins
# dropped : residency
# dropped : cirque
# dropped : soleil
# dropped : zed
# dropped : zarkana
# dropped : radio
# dropped : hall
# dropped : metropolitan
# dropped : wagner
# dropped : parsifal
# dropped : dortoir
# dropped : gabriel
# dropped : carceri
# dropped : bach
# dropped : fleurs
# dropped : mots
# dropped : nods
# dropped : c.r.a.z.y
# dropped : financial
# dropped : followup
# dropped : flore
# dropped : dallas
# dropped : buyers
# dropped : demolition
# dropped : watts
# dropped : mexican-american
# dropped : comedians
# dropped : o'brien
# dropped : dana
# dropped : carvey
# dropped : pootie
# dropped : tang
# dropped : short-lived
# dropped : lucky
# dropped : semi-autobiographical
# dropped : comedy-drama
# dropped : produces
# dropped : hustle
# dropped : jasmine
# dropped : trumbo
# dropped : horace
# dropped : pete
# dropped : houston
# dropped : directly
# dropped : direct-to-fan
# dropped : tickets
# dropped : drm-free
# dropped : downloads
# dropped : albums
# dropped : observational
# dropped : self-deprecating
# dropped : vulgar
# dropped : beacon
# dropped : shameless
# dropped : divine
# dropped : congressman
# dropped : medieval
# dropped : jungian
# dropped : psychoanalyst
# dropped : seminary
# dropped : georgia
# dropped : mayor
# dropped : cincinnati
# dropped : degrimston
# dropped : aka
# dropped : church
# dropped : oregon
# dropped : linn
# dropped : lieutenant
# dropped : governor
# dropped : nebraska
# dropped : ross
# dropped : rowan
# dropped : neurologist
# dropped : chronobiologist
# dropped : szifron
# dropped : simuladores
# dropped : writer-director
# dropped : tales
# dropped : laurence
# dropped : praemium
# dropped : imperiale
# dropped : italia
# dropped : marat/sade
# dropped : transferred
# dropped : famously
# dropped : zemeckis
# dropped : sequels
# dropped : associate
# dropped : anna
# dropped : boden
# dropped : half
# dropped : nelson
# dropped : sugar
# dropped : mississippi
# dropped : grind
# dropped : attracted
# dropped : secondhand
# dropped : dennis
# dropped : menace
# dropped : strikes
# dropped : c.m
# dropped : swiss-canadian
# dropped : teaches
# dropped : uqam
# dropped : anne
# dropped : trister
# dropped : free
# dropped : emporte-moi
# dropped : ecumenical
# dropped : ontario
# dropped : relations
# dropped : returning
# dropped : nod
# dropped : amandla
# dropped : stenberg
# dropped : nick
# dropped : line
# dropped : wolverine
# dropped : yuma
# dropped : pilots
# dropped : trees
# dropped : nyc
# dropped : generally
# dropped : xiaoshuai
# dropped : lou
# dropped : quan'an
# dropped : province
# dropped : shanxi
# dropped : state-run
# dropped : bureaucracy
# dropped : therefore
# dropped : status
# dropped : allowed
# dropped : npr
# dropped : powers
# dropped : defined
# dropped : bits
# dropped : postmodernism
# dropped : instills
# dropped : extensive
# dropped : thoughts
# dropped : emotions
# dropped : mental
# dropped : deconstruction
# dropped : moyoko
# dropped : animage
# dropped : nadia
# dropped : avant-garde
# dropped : face
# dropped : accomplishing
# dropped : trabzon
# dropped : istanbul
# dropped : turkey
# dropped : arzu
# dropped : plumpe
# dropped : schopenhauer
# dropped : nietzsche
# dropped : ibsen
# dropped : seen
# dropped : reinhardt
# dropped : commander
# dropped : eastern
# dropped : front
# dropped : crashes
# dropped : without
# dropped : severe
# dropped : nosferatu
# dropped : bram
# dropped : dracula
# dropped : copyright
# dropped : expressionist
# dropped : laugh
# dropped : interpretation
# dropped : goethe
# dropped : faust
# dropped : emigrated
# dropped : sunrise
# dropped : devils
# dropped : travelled
# dropped : flaherty
# dropped : disputes
# dropped : finish
# dropped : injuries
# dropped : automobile
# dropped : occurred
# dropped : pacific
# dropped : coast
# dropped : rincon
# dropped : southeast
# dropped : reel
# dropped : marizza
# dropped : genannt
# dropped : schmuggler-madonna
# dropped : survives
# dropped : leaves
# dropped : entirety
# dropped : jeffrey
# dropped : jacob
# dropped : regarding
# dropped : forever
# dropped : armageddon
# dropped : cloverfield
# dropped : felicity
# dropped : alias
# dropped : fringe
# dropped : darkness
# dropped : frequent
# dropped : burk
# dropped : greg
# dropped : grunberg
# dropped : simon
# dropped : pegg
# dropped : alex
# dropped : kurtzman
# dropped : roberto
# dropped : orci
# dropped : giacchino
# dropped : mindel
# dropped : larry
# dropped : fong
# dropped : maryann
# dropped : markey
# dropped : portrayals
# dropped : jabituya
# dropped : renamed
# dropped : chuck
# dropped : fishman
# dropped : villainous
# dropped : genius
# dropped : eugene
# dropped : belford
# dropped : recent
# dropped : crazy
# dropped : dicaprio-produced
# dropped : flood
# dropped : scorsese
# dropped : dramatist
# dropped : bbs
# dropped : renowned
# dropped : visually
# dropped : tears
# dropped : ashes
# dropped : chungking
# dropped : express
# dropped : fallen
# dropped : happy
# dropped : grandmaster
# dropped : maggie
# dropped : cheung
# dropped : leung
# dropped : yearn
# dropped : midst
# dropped : knowingly
# dropped : sketchy
# dropped : digressive
# dropped : exhilarating
# dropped : tromeo
# dropped : unleashed
# dropped : dawn
# dropped : slither
# dropped : porn
# dropped : vol
# dropped : portree
# dropped : scotsman
# dropped : consequently
# dropped : picked
# dropped : captured
# dropped : cup
# dropped : jekyll
# dropped : nesbitt
# dropped : michelle
# dropped : ryan
# dropped : gina
# dropped : bellman
# dropped : least
# dropped : bodies
# dropped : gentlemen
# dropped : relish
# dropped : hood
# dropped : shotgun
# dropped : freeway
# dropped : drives
# dropped : thru
# dropped : l.a
# dropped : grammys
# dropped : muddy
# dropped : waters
# dropped : satisfied
# dropped : respect
# dropped : stax
# dropped : cool
# dropped : birth
# dropped : stardom
# dropped : newest
# dropped : strangers
# dropped : select
# dropped : tribeca
# dropped : gordon
# dropped : enemies
# dropped : shortlisted
# dropped : richards
# dropped : abstract
# dropped : capote
# dropped : moneyball
# dropped : foxcatcher
# dropped : bobby
# dropped : fischer
# dropped : reserved
# dropped : rory
# dropped : kennedy
# dropped : nina
# dropped : narrated
# dropped : scored
# dropped : sabbath
# dropped : pieter
# dropped : fredericia
# dropped : spans
# dropped : addresses
# dropped : sicilian-american
# dropped : redemption
# dropped : faith
# dropped : machismo
# dropped : gang
# dropped : conflict
# dropped : depiction
# dropped : liberal
# dropped : nonprofit
# dropped : organization
# dropped : dedicated
# dropped : preservation
# dropped : afi
# dropped : globes
# dropped : mean
# dropped : vigilante-thriller
# dropped : taxi
# dropped : driver
# dropped : raging
# dropped : bull
# dropped : temptation
# dropped : goodfellas
# dropped : cape
# dropped : casino
# dropped : niro
# dropped : dicaprio
# dropped : gangs
# dropped : wolf
# dropped : wall
# dropped : resulted
# dropped : waltz
# dropped : shutter
# dropped : boardwalk
# dropped : vinyl
# dropped : tied
# dropped : wilder
# dropped : overall
# dropped : honoured
# dropped : padma
# dropped : shri
# dropped : khamoshi
# dropped : hum
# dropped : dil
# dropped : chuke
# dropped : sanam
# dropped : devdas
# dropped : additional
# dropped : flop
# dropped : saawariya
# dropped : guzaarish
# dropped : tragic
# dropped : goliyon
# dropped : box-office
# dropped : collections
# dropped : kom
# dropped : bajirao
# dropped : mastani
# dropped : otto
# dropped : fades
# dropped : ripper
# dropped : bait

# %%
df = df_backup.copy()

# %%
# On pondère les mots par leur nb d'occurence (en fait je suis juste en train de recoder TfidfVectorizer lol)
# pour renforcer l'importance des mots qui apparaissent peu
for key in df:
    df[key] = df[key]/df.sum(axis=0)[key]

# %%
#On clusterise
km = KMeans(n_clusters = 10,init="k-means++",max_iter=100,n_init=1,verbose=True)
X = df.loc[:,:]
km.fit(X)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 554.746970605
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 552.980226953
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 551.279111963
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 551.279111963
# center shift 0.000000e+00 within tolerance 1.715990e-07
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=10, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=True)

# %%
km.labels_
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 8,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6, 7, 7, 7, 7, 7, 7, 7, 4,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 9, 7, 7, 7, 0, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 3, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 1, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 1, 7, 7,
#        7, 7, 7, 7, 7, 7, 5, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 2, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7])

# %%
#Ecriture dans un fichier
df_backup.to_csv("temp.csv",encoding='utf-8', sep=";")
